# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mshiha'

# %%
print(os.listdir(os.getcwd()))
# Out:
# ['.anaconda', '.cisco', '.conda', '.condarc', '.config', '.Icecream Screen Recorder', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.PyCharmCE2019.2', '.spyder-py3', '01-Decision Trees and Random Forests in Python.ipynb', '01-K Means Clustering with Python.ipynb', '01-NLP (Natural Language Processing) with Python.ipynb', '01-Principal Component Analysis.ipynb', '01-Support Vector Machines with Python.ipynb', '02-Decision Trees and Random Forest Project.ipynb', '02-K Means Clustering Project.ipynb', '02-K Nearest Neighbors Project.ipynb', '02-Logistic Regression Project.ipynb', '02-NLP Project.ipynb', '02-Support Vector Machines Project.ipynb', '03-Decision Trees and Random Forest Project - Solutions.ipynb', '03-K Means Clustering Project - Solutions.ipynb', '03-NLP Project - Solutions.ipynb', '03-Support Vector Machines Project - Solutions.ipynb', '3D Objects', 'AB_NYC_2019.csv', 'advertising.csv', 'age_gender_bkts.csv', 'Air BNB second Trial.ipynb', 'AIR BNB-Seedo.ipynb', 'AppData', 'Application Data', 'California Housing Prices Prediction.ipynb', 'Classified Data', 'College_Data', 'Contacts', 'Cookies', 'countries.csv', 'Country.csv', 'CountryNotes.csv', 'database.sqlite', 'Desktop', 'Documents', 'Downloads', 'Dropbox', 'Ecommerce Customers', 'Favorites', 'Footnotes.csv', 'hashes.txt', 'housing.csv', 'iBwave Drive', 'Indicators.csv', 'IntelGraphicsProfiles', 'IRIS Flower', 'Iris Flower.ipynb', 'IRIS.csv', 'Irish Flower.ipynb', 'KNN_Project_Data', 'kyphosis.csv', 'Linear Regression', 'Linear Regression Project.ipynb', 'Linear Regression.ipynb', 'Links', 'loan_data.csv', 'Local Settings', 'Logistic Regression.ipynb', 'MicrosoftEdgeBackups', 'Music', 'My Documents', 'NetHood', 'New User Booking (1).ipynb', 'New User Booking -Final.ipynb', 'New User Booking -Scenario 2.ipynb', 'New User Booking -Scenario 3.ipynb', 'New User Booking -Scenario 4.ipynb', 'Newyork City Airbnb.ipynb', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{fd9a35db-49fe-11e9-aa2c-248a07783950}.TM.blf', 'NTUSER.DAT{fd9a35db-49fe-11e9-aa2c-248a07783950}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{fd9a35db-49fe-11e9-aa2c-248a07783950}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'NYC Airbnb.ipynb', 'OneDrive', 'PCA.png', 'Pictures', 'PrintHood', 'PycharmProjects', 'readme', 'Recent', 'repo', 'Salaries.csv', 'sample_submission_NDF.csv', 'Saved Games', 'Scenario 1.ipynb', 'Scenario 2(LR).ipynb', 'Scenario 2-(Linear regression).ipynb', 'scenario-dropping.ipynb', 'seaborn-data', 'Searches', 'SendTo', 'Series.csv', 'SeriesNotes.csv', 'sessions.csv', 'sf-salaries.zip', 'smsspamcollection', 'soccer', 'soccer.zip', 'Start Menu', 'Templates', 'test_users.csv', 'titanic_test.csv', 'titanic_train.csv', 'train_users_2.csv', 'Udemy,python till Linear Regression.ipynb', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Untitled6.ipynb', 'Untitled7.ipynb', 'Untitled8.ipynb', 'USA_Housing.csv', 'VEctorization demo-Deep learning Course.ipynb', 'Videos', 'xgboost-1.3.3-pp37-pypy37_pp73-win32.whl', 'yelp.csv', 'zizo.ipynb']

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Importing CSV files and finding their info

# %%
train_users=pd.read_csv('train_users_2.csv')

# %%
train_users.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US

# %%
train_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null object
# timestamp_first_active     213451 non-null int64
# date_first_booking         88908 non-null object
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 26.1+ MB

# %%
train_users.shape
# Out:
# (213451, 16)

# %%
#There are many missing values for age,date_first_booking,first_affiliate_tracked#

# %%
test_users=pd.read_csv('test_users.csv')

# %%
test_users.head()
# Out:
#            id date_account_created  timestamp_first_active  \
# 0  5uwns89zht           2014-07-01          20140701000006
# 1  jtl0dijy2j           2014-07-01          20140701000051
# 2  xx0ulgorjt           2014-07-01          20140701000148
# 3  6c6puo6ix0           2014-07-01          20140701000215
# 4  czqhjk3yfe           2014-07-01          20140701000305
#
#    date_first_booking     gender   age signup_method  signup_flow language  \
# 0                 NaN     FEMALE  35.0      facebook            0       en
# 1                 NaN  -unknown-   NaN         basic            0       en
# 2                 NaN  -unknown-   NaN         basic            0       en
# 3                 NaN  -unknown-   NaN         basic            0       en
# 4                 NaN  -unknown-   NaN         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0            direct             direct               untracked      Moweb
# 1            direct             direct               untracked      Moweb
# 2            direct             direct                  linked        Web
# 3            direct             direct                  linked        Web
# 4            direct             direct               untracked        Web
#
#   first_device_type  first_browser
# 0            iPhone  Mobile Safari
# 1            iPhone  Mobile Safari
# 2   Windows Desktop         Chrome
# 3   Windows Desktop             IE
# 4       Mac Desktop         Safari

# %%
test_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62096 entries, 0 to 62095
# Data columns (total 15 columns):
# id                         62096 non-null object
# date_account_created       62096 non-null object
# timestamp_first_active     62096 non-null int64
# date_first_booking         0 non-null float64
# gender                     62096 non-null object
# age                        33220 non-null float64
# signup_method              62096 non-null object
# signup_flow                62096 non-null int64
# language                   62096 non-null object
# affiliate_channel          62096 non-null object
# affiliate_provider         62096 non-null object
# first_affiliate_tracked    62076 non-null object
# signup_app                 62096 non-null object
# first_device_type          62096 non-null object
# first_browser              62096 non-null object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 7.1+ MB

# %%
test_users.shape
# Out:
# (62096, 15)

# %%
####All the date_first_booking data are misiing in tne test data

# %%
countries=pd.read_csv('countries.csv')

# %%
countries.head()
# Out:
#   country_destination  lat_destination  lng_destination  distance_km  \
# 0                  AU       -26.853388       133.275160   15297.7440
# 1                  CA        62.393303       -96.818146    2828.1333
# 2                  DE        51.165707        10.452764    7879.5680
# 3                  ES        39.896027        -2.487694    7730.7240
# 4                  FR        46.232193         2.209667    7682.9450
#
#    destination_km2 destination_language   language_levenshtein_distance
# 0        7741220.0                   eng                           0.00
# 1        9984670.0                   eng                           0.00
# 2         357022.0                   deu                          72.61
# 3         505370.0                   spa                          92.25
# 4         643801.0                   fra                          92.06

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
# country_destination              10 non-null object
# lat_destination                  10 non-null float64
# lng_destination                  10 non-null float64
# distance_km                      10 non-null float64
# destination_km2                  10 non-null float64
# destination_language             10 non-null object
# language_levenshtein_distance    10 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 640.0+ bytes

# %%
countries.shape
# Out:
# (10, 7)

# %%
age_gender=pd.read_csv('age_gender_bkts.csv')

# %%
age_gender.tail()
# Out:
#     age_bucket country_destination  gender  population_in_thousands    year
# 415      95-99                  US    male                    115.0  2015.0
# 416      90-94                  US    male                    541.0  2015.0
# 417      15-19                  US  female                  10570.0  2015.0
# 418      85-89                  US    male                   1441.0  2015.0
# 419      80-84                  US    male                   2442.0  2015.0

# %%
age_gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 5 columns):
# age_bucket                 420 non-null object
# country_destination        420 non-null object
# gender                     420 non-null object
# population_in_thousands    420 non-null float64
# year                       420 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 16.5+ KB

# %%
age_gender.shape
# Out:
# (420, 5)

# %%
sessions=pd.read_csv('sessions.csv')

# %%
sessions.head()
# Out:
#       user_id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
# 4  d1mm9tcy42          lookup         NaN                  NaN
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0
# 4  Windows Desktop         435.0

# %%
sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10567737 entries, 0 to 10567736
# Data columns (total 6 columns):
# user_id          object
# action           object
# action_type      object
# action_detail    object
# device_type      object
# secs_elapsed     float64
# dtypes: float64(1), object(5)
# memory usage: 483.8+ MB

# %%
sessions.shape
# Out:
# (10567737, 6)

# %%
sample=pd.read_csv('sample_submission_NDF.csv')

# %%
sample.head()
# Out:
#            id country
# 0  5uwns89zht     NDF
# 1  jtl0dijy2j     NDF
# 2  xx0ulgorjt     NDF
# 3  6c6puo6ix0     NDF
# 4  czqhjk3yfe     NDF

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62096 entries, 0 to 62095
# Data columns (total 2 columns):
# id         62096 non-null object
# country    62096 non-null object
# dtypes: object(2)
# memory usage: 970.3+ KB

# %%
sample.shape
# Out:
# (62096, 2)

# %% [markdown]
# ## EXploring training data##

# %%
train_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null object
# timestamp_first_active     213451 non-null int64
# date_first_booking         88908 non-null object
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 26.1+ MB

# %% [markdown]
# #There are many missing values for age,date_first_booking,first_affiliate_tracked#

# %% [markdown]
# ## We will check if age_gender bucket data can help us with missing values of age###

# %%
age_gender['country_destination'].unique()
# Out:
# array(['AU', 'CA', 'DE', 'ES', 'FR', 'GB', 'IT', 'NL', 'PT', 'US'],
#       dtype=object)

# %%
age_gender[age_gender['country_destination']=='US']
# Out:
#     age_bucket country_destination  gender  population_in_thousands    year
# 378      90-94                  US  female                   1193.0  2015.0
# 379      75-79                  US    male                   3641.0  2015.0
# 380      70-74                  US    male                   5278.0  2015.0
# 381      65-69                  US    male                   7561.0  2015.0
# 382      60-64                  US    male                   9217.0  2015.0
# 383      55-59                  US    male                  10689.0  2015.0
# 384      50-54                  US    male                  11013.0  2015.0
# 385      45-49                  US    male                  10454.0  2015.0
# 386      40-44                  US    male                  10159.0  2015.0
# 387      10-14                  US  female                  10346.0  2015.0
# 388      35-39                  US    male                  10329.0  2015.0
# 389      30-34                  US    male                  10984.0  2015.0
# 390      25-29                  US    male                  11385.0  2015.0
# 391      20-24                  US    male                  11601.0  2015.0
# 392      15-19                  US    male                  11025.0  2015.0
# 393      10-14                  US    male                  10771.0  2015.0
# 394        5-9                  US    male                  10632.0  2015.0
# 395        0-4                  US    male                  10788.0  2015.0
# 396       100+                  US  female                     61.0  2015.0
# 397      95-99                  US  female                    361.0  2015.0
# 398        5-9                  US  female                  10201.0  2015.0
# 399      85-89                  US  female                   2459.0  2015.0
# 400      80-84                  US  female                   3394.0  2015.0
# 401      75-79                  US  female                   4532.0  2015.0
# 402      70-74                  US  female                   6179.0  2015.0
# 403      65-69                  US  female                   8483.0  2015.0
# 404      60-64                  US  female                  10004.0  2015.0
# 405      55-59                  US  female                  11264.0  2015.0
# 406      50-54                  US  female                  11413.0  2015.0
# 407      45-49                  US  female                  10659.0  2015.0
# 408        0-4                  US  female                  10306.0  2015.0
# 409      40-44                  US  female                  10308.0  2015.0
# 410      35-39                  US  female                  10352.0  2015.0
# 411      30-34                  US  female                  10863.0  2015.0
# 412      25-29                  US  female                  11011.0  2015.0
# 413      20-24                  US  female                  11094.0  2015.0
# 414       100+                  US    male                     13.0  2015.0
# 415      95-99                  US    male                    115.0  2015.0
# 416      90-94                  US    male                    541.0  2015.0
# 417      15-19                  US  female                  10570.0  2015.0
# 418      85-89                  US    male                   1441.0  2015.0
# 419      80-84                  US    male                   2442.0  2015.0

# %%
age_gender.groupby(['gender','country_destination']).mean()
# Out:
#                             population_in_thousands    year
# gender country_destination
# female AU                                572.571429  2015.0
#        CA                                860.285714  2015.0
#        DE                               1999.857143  2015.0
#        ES                               1136.666667  2015.0
#        FR                               1594.904762  2015.0
#        GB                               1540.238095  2015.0
#        IT                               1495.476190  2015.0
#        NL                                404.095238  2015.0
#        PT                                260.380952  2015.0
#        US                               7859.666667  2015.0
# male   AU                                566.619048  2015.0
#        CA                                847.857143  2015.0
#        DE                               1931.666667  2015.0
#        ES                               1111.095238  2015.0
#        FR                               1499.523810  2015.0
#        GB                               1499.761905  2015.0
#        IT                               1416.190476  2015.0
#        NL                                398.190476  2015.0
#        PT                                244.809524  2015.0
#        US                               7622.809524  2015.0

# %%
age_gender.groupby(['age_bucket','country_destination']).count()
# Out:
#                                 gender  population_in_thousands  year
# age_bucket country_destination
# 0-4        AU                        2                        2     2
#            CA                        2                        2     2
#            DE                        2                        2     2
#            ES                        2                        2     2
#            FR                        2                        2     2
#            GB                        2                        2     2
#            IT                        2                        2     2
#            NL                        2                        2     2
#            PT                        2                        2     2
#            US                        2                        2     2
# 10-14      AU                        2                        2     2
#            CA                        2                        2     2
#            DE                        2                        2     2
#            ES                        2                        2     2
#            FR                        2                        2     2
#            GB                        2                        2     2
#            IT                        2                        2     2
#            NL                        2                        2     2
#            PT                        2                        2     2
#            US                        2                        2     2
# 100+       AU                        2                        2     2
#            CA                        2                        2     2
#            DE                        2                        2     2
#            ES                        2                        2     2
#            FR                        2                        2     2
#            GB                        2                        2     2
#            IT                        2                        2     2
#            NL                        2                        2     2
#            PT                        2                        2     2
#            US                        2                        2     2
# ...                                ...                      ...   ...
# 85-89      AU                        2                        2     2
#            CA                        2                        2     2
#            DE                        2                        2     2
#            ES                        2                        2     2
#            FR                        2                        2     2
#            GB                        2                        2     2
#            IT                        2                        2     2
#            NL                        2                        2     2
#            PT                        2                        2     2
#            US                        2                        2     2
# 90-94      AU                        2                        2     2
#            CA                        2                        2     2
#            DE                        2                        2     2
#            ES                        2                        2     2
#            FR                        2                        2     2
#            GB                        2                        2     2
#            IT                        2                        2     2
#            NL                        2                        2     2
#            PT                        2                        2     2
#            US                        2                        2     2
# 95-99      AU                        2                        2     2
#            CA                        2                        2     2
#            DE                        2                        2     2
#            ES                        2                        2     2
#            FR                        2                        2     2
#            GB                        2                        2     2
#            IT                        2                        2     2
#            NL                        2                        2     2
#            PT                        2                        2     2
#            US                        2                        2     2
#
# [210 rows x 3 columns]

# %% [markdown]
# ### Concatinating train and test data####

# %%
df=pd.concat([train_users,test_users],axis=0)
# Out:
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#   affiliate_channel affiliate_provider   age country_destination  \
# 0            direct             direct   NaN                 NDF
# 1               seo             google  38.0                 NDF
# 2            direct             direct  56.0                  US
# 3            direct             direct  42.0               other
# 4            direct             direct  41.0                  US
#
#   date_account_created date_first_booking first_affiliate_tracked  \
# 0           2010-06-28                NaN               untracked
# 1           2011-05-25                NaN               untracked
# 2           2010-09-28         2010-08-02               untracked
# 3           2011-12-05         2012-09-08               untracked
# 4           2010-09-14         2010-02-18               untracked
#
#   first_browser first_device_type     gender          id language signup_app  \
# 0        Chrome       Mac Desktop  -unknown-  gxn3p5htnn       en        Web
# 1        Chrome       Mac Desktop       MALE  820tgsjxq7       en        Web
# 2            IE   Windows Desktop     FEMALE  4ft3gnwmtx       en        Web
# 3       Firefox       Mac Desktop     FEMALE  bjjt8pjhuk       en        Web
# 4        Chrome       Mac Desktop  -unknown-  87mebub9p4       en        Web
#
#    signup_flow signup_method  timestamp_first_active
# 0            0      facebook          20090319043255
# 1            0      facebook          20090523174809
# 2            3         basic          20090609231247
# 3            0      facebook          20091031060129
# 4            0         basic          20091208061105

# %%
df.shape
# Out:
# (275547, 16)

# %%
df.tail()
# Out:
#       affiliate_channel affiliate_provider   age country_destination  \
# 62091            direct             direct  31.0                 NaN
# 62092            direct             direct   NaN                 NaN
# 62093            direct             direct   NaN                 NaN
# 62094         sem-brand             google   NaN                 NaN
# 62095             other              other  49.0                 NaN
#
#       date_account_created date_first_booking first_affiliate_tracked  \
# 62091           2014-09-30                NaN               untracked
# 62092           2014-09-30                NaN               untracked
# 62093           2014-09-30                NaN                  linked
# 62094           2014-09-30                NaN                     omg
# 62095           2014-09-30                NaN           tracked-other
#
#       first_browser first_device_type     gender          id language  \
# 62091            IE   Windows Desktop  -unknown-  cv0na2lf5a       en
# 62092     -unknown-     Android Phone  -unknown-  zp8xfonng8       ko
# 62093       Firefox   Windows Desktop  -unknown-  fa6260ziny       de
# 62094        Safari       Mac Desktop  -unknown-  87k0fy4ugm       en
# 62095        Chrome   Windows Desktop     FEMALE  9uqfg8txu3       en
#
#       signup_app  signup_flow signup_method  timestamp_first_active
# 62091        Web            0         basic          20140930235232
# 62092    Android           23         basic          20140930235306
# 62093        Web            0         basic          20140930235408
# 62094        Web            0         basic          20140930235430
# 62095        Web            0         basic          20140930235901

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275547 entries, 0 to 62095
# Data columns (total 16 columns):
# affiliate_channel          275547 non-null object
# affiliate_provider         275547 non-null object
# age                        158681 non-null float64
# country_destination        213451 non-null object
# date_account_created       275547 non-null object
# date_first_booking         88908 non-null object
# first_affiliate_tracked    269462 non-null object
# first_browser              275547 non-null object
# first_device_type          275547 non-null object
# gender                     275547 non-null object
# id                         275547 non-null object
# language                   275547 non-null object
# signup_app                 275547 non-null object
# signup_flow                275547 non-null int64
# signup_method              275547 non-null object
# timestamp_first_active     275547 non-null int64
# dtypes: float64(1), int64(2), object(13)
# memory usage: 35.7+ MB

# %% [markdown]
# ## Creating a copy of the data frame to work on

# %%
df_2=df.copy()

# %% [markdown]
# ## Data Exploration

# %%
###Analyzing age####
df_2.age.nunique()
# Out:
# 145

# %%
sns.set(style='whitegrid',palette='deep',font_scale=1,rc=None)
sns.set_context('paper')
sns.boxplot(x='age',y='country_destination',data=df_2)

# %% [markdown]
# #### It is obvious that there are many outliers in the age

# %%
df_2[df_2.age>110]
# Out:
#       affiliate_channel affiliate_provider     age country_destination  \
# 388               other         craigslist  2014.0                  FR
# 673               other         craigslist  2014.0                 NDF
# 1040              other         craigslist  2014.0                  US
# 1177             direct             direct  2013.0                  US
# 1200             direct             direct  2014.0                  US
# 1239             direct             direct  2014.0                  CA
# 1257             direct             direct  2014.0                  US
# 1308              other         craigslist  2014.0                 NDF
# 1474              other         craigslist  2014.0                 NDF
# 1502      sem-non-brand             google  2014.0                  US
# 1826             direct             direct  2014.0               other
# 1860                seo             google  2014.0                  US
# 2228              other         craigslist   115.0                 NDF
# 2582      sem-non-brand             google  2014.0                  FR
# 3818          sem-brand             google  2014.0                 NDF
# 4292      sem-non-brand              other  2013.0                  US
# 5091      sem-non-brand             google  2014.0                  US
# 5331      sem-non-brand             google  2014.0                 NDF
# 5549             direct             direct  2014.0                  US
# 5638      sem-non-brand             google  2014.0                  US
# 5706              other         craigslist  2014.0                 NDF
# 5710                seo             google  2014.0                 NDF
# 5735                seo             google  2014.0                  US
# 5989                seo             google  2014.0                  US
# 6695      sem-non-brand             google  2014.0                 NDF
# 6925             direct              other  2014.0               other
# 7097            content             google  2014.0                  US
# 7185              other         craigslist  2013.0                  US
# 7360             direct             direct  2014.0                  DE
# 7505                seo             google  2014.0                 NDF
# ...                 ...                ...     ...                 ...
# 32624            direct             direct  1939.0                 NaN
# 32878         sem-brand             google  1951.0                 NaN
# 33882            direct             direct  1928.0                 NaN
# 34179            direct             direct  1920.0                 NaN
# 37137            direct             direct  2001.0                 NaN
# 37792             other          padmapper  1923.0                 NaN
# 39437            direct             direct  1926.0                 NaN
# 39469            direct             direct  1928.0                 NaN
# 40954            direct             direct  1920.0                 NaN
# 43932            direct             direct  1925.0                 NaN
# 44602            direct             direct  1925.0                 NaN
# 45381            direct             direct  1934.0                 NaN
# 45586            direct             direct  1927.0                 NaN
# 45617            direct             direct  1933.0                 NaN
# 47647            direct             direct  2001.0                 NaN
# 47761            direct             direct  1934.0                 NaN
# 49302            direct             direct  1933.0                 NaN
# 49575            direct             direct  1935.0                 NaN
# 53555            direct             direct  1948.0                 NaN
# 53817            direct             direct  2002.0                 NaN
# 55313     sem-non-brand             google  1941.0                 NaN
# 55620            direct             direct  1951.0                 NaN
# 55957            direct             direct  2001.0                 NaN
# 57659            direct             direct  1924.0                 NaN
# 57968            direct             direct  1944.0                 NaN
# 58576            direct             direct  1927.0                 NaN
# 58828            direct             direct  1935.0                 NaN
# 59186            direct             direct  1923.0                 NaN
# 60173            direct             direct  1927.0                 NaN
# 60268            direct             direct  2001.0                 NaN
#
#       date_account_created date_first_booking first_affiliate_tracked  \
# 388             2010-04-11         2010-04-13               untracked
# 673             2010-05-25                NaN               untracked
# 1040            2010-07-14         2010-07-15               untracked
# 1177            2010-07-25         2010-07-26               untracked
# 1200            2010-07-27         2010-07-29               untracked
# 1239            2010-07-30         2010-07-30               untracked
# 1257            2010-08-01         2010-08-01               untracked
# 1308            2010-08-06                NaN                  linked
# 1474            2010-08-21                NaN               untracked
# 1502            2010-08-24         2010-08-25               untracked
# 1826            2010-09-21         2010-09-26               untracked
# 1860            2010-09-23         2011-03-25                  linked
# 2228            2010-10-29                NaN                     NaN
# 2582            2010-12-06         2010-12-06                  linked
# 3818            2011-03-22                NaN               untracked
# 4292            2011-04-17         2012-02-05               untracked
# 5091            2011-05-23         2011-08-15               untracked
# 5331            2011-06-02                NaN               untracked
# 5549            2011-06-10         2012-01-17                     omg
# 5638            2011-06-13         2011-06-15               untracked
# 5706            2011-06-15                NaN               untracked
# 5710            2011-06-15                NaN                  linked
# 5735            2011-06-16         2011-10-27                  linked
# 5989            2011-06-27         2011-08-01               untracked
# 6695            2011-07-19                NaN               untracked
# 6925            2011-07-26         2011-07-26               untracked
# 7097            2011-07-31         2011-08-07               untracked
# 7185            2011-08-02         2011-08-17               untracked
# 7360            2011-08-07         2011-08-21               untracked
# 7505            2011-08-11                NaN                     NaN
# ...                    ...                ...                     ...
# 32624           2014-08-16                NaN               untracked
# 32878           2014-08-16                NaN                     omg
# 33882           2014-08-18                NaN               untracked
# 34179           2014-08-18                NaN               untracked
# 37137           2014-08-23                NaN               untracked
# 37792           2014-08-24                NaN           tracked-other
# 39437           2014-08-26                NaN               untracked
# 39469           2014-08-26                NaN               untracked
# 40954           2014-08-28                NaN               untracked
# 43932           2014-09-02                NaN               untracked
# 44602           2014-09-02                NaN               untracked
# 45381           2014-09-04                NaN               untracked
# 45586           2014-09-04                NaN               untracked
# 45617           2014-09-04                NaN               untracked
# 47647           2014-09-07                NaN               untracked
# 47761           2014-09-08                NaN               untracked
# 49302           2014-09-10                NaN               untracked
# 49575           2014-09-10                NaN               untracked
# 53555           2014-09-17                NaN               untracked
# 53817           2014-09-17                NaN               untracked
# 55313           2014-09-19                NaN                     omg
# 55620           2014-09-20                NaN               untracked
# 55957           2014-09-21                NaN               untracked
# 57659           2014-09-23                NaN               untracked
# 57968           2014-09-24                NaN               untracked
# 58576           2014-09-25                NaN               untracked
# 58828           2014-09-25                NaN               untracked
# 59186           2014-09-26                NaN               untracked
# 60173           2014-09-27                NaN               untracked
# 60268           2014-09-28                NaN               untracked
#
#        first_browser first_device_type     gender          id language  \
# 388          Firefox   Windows Desktop  -unknown-  v2x0ms9c62       en
# 673           Safari       Mac Desktop     FEMALE  umf1wdk9uc       en
# 1040          Chrome       Mac Desktop       MALE  m82epwn7i8       en
# 1177          Chrome       Mac Desktop       MALE  2th813zdx7       en
# 1200              IE   Windows Desktop     FEMALE  3amf04n3o3       en
# 1239         Firefox       Mac Desktop     FEMALE  6vpmryt377       en
# 1257          Chrome   Windows Desktop       MALE  uxy91xb5p2       en
# 1308          Chrome   Windows Desktop       MALE  bno0vva4uz       en
# 1474          Safari       Mac Desktop       MALE  h3rrmak4tu       pt
# 1502          Chrome   Windows Desktop     FEMALE  fou0j7fhnm       en
# 1826         Firefox       Mac Desktop  -unknown-  kfeh5350pi       en
# 1860              IE   Windows Desktop     FEMALE  9aouhu15rk       en
# 2228       -unknown-     Other/Unknown       MALE  i0j7vqzk2m       en
# 2582   Mobile Safari              iPad  -unknown-  aq0lqrjf2y       en
# 3818          Safari       Mac Desktop     FEMALE  1w7fdi5pxc       en
# 4292          Chrome   Windows Desktop     FEMALE  8yv90v3y1f       en
# 5091    AOL Explorer   Windows Desktop       MALE  0pyobdy4pq       en
# 5331         Firefox   Windows Desktop  -unknown-  ezqp4a8cmw       en
# 5549          Safari       Mac Desktop     FEMALE  dguhdfl2l2       en
# 5638         Firefox       Mac Desktop     FEMALE  l56119iwg5       en
# 5706          Chrome       Mac Desktop  -unknown-  w3fb6io74e       en
# 5710          Safari       Mac Desktop     FEMALE  ybblb7wzh8       en
# 5735         Firefox       Mac Desktop     FEMALE  bbt3xydhoj       en
# 5989          Chrome       Mac Desktop       MALE  k1j9tg9tz2       en
# 6695              IE   Windows Desktop       MALE  fv4mcbvonv       en
# 6925       -unknown-            iPhone     FEMALE  8smg1h6o7t       en
# 7097              IE   Windows Desktop     FEMALE  n2wz02fa45       en
# 7185       -unknown-     Android Phone     FEMALE  t92xz5zq9f       en
# 7360          Chrome       Mac Desktop       MALE  i4ko79m5l9       en
# 7505       -unknown-     Other/Unknown       MALE  ivpksyyguz       en
# ...              ...               ...        ...         ...      ...
# 32624      -unknown-     Android Phone       MALE  jx47w6i77o       en
# 32878         Chrome   Windows Desktop     FEMALE  ke849urmu8       en
# 33882      -unknown-     Android Phone       MALE  6ldmppn1s5       en
# 34179      -unknown-     Android Phone     FEMALE  vizrptkjzb       en
# 37137  Chrome Mobile     Android Phone       MALE  h542s4qoug       en
# 37792         Chrome   Windows Desktop       MALE  kwt50fmym9       en
# 39437      -unknown-     Other/Unknown     FEMALE  8l2hplddaj       en
# 39469      -unknown-     Android Phone       MALE  tekotgmj26       en
# 40954      -unknown-     Android Phone     FEMALE  8m74jsbf1c       en
# 43932      -unknown-     Android Phone     FEMALE  m9au839jvq       en
# 44602             IE   Windows Desktop  -unknown-  2mjg9mei0r       en
# 45381      -unknown-     Android Phone       MALE  aedeaxjgw1       en
# 45586      -unknown-     Android Phone     FEMALE  758ofdyrxy       ko
# 45617      -unknown-     Android Phone       MALE  f9iszdxugr       en
# 47647      -unknown-     Android Phone  -unknown-  tabqiq60o6       en
# 47761      -unknown-     Android Phone     FEMALE  jsy8xw1qfj       en
# 49302      -unknown-     Android Phone     FEMALE  da4iqraggn       en
# 49575      -unknown-     Android Phone       MALE  a3dkr9bd5m       en
# 53555      -unknown-     Android Phone       MALE  419z5rk8ol       en
# 53817      -unknown-     Android Phone     FEMALE  wor5bfp24a       en
# 55313         Chrome   Windows Desktop       MALE  adqgaszjft       en
# 55620      -unknown-     Android Phone       MALE  uvkssc8m12       ko
# 55957      -unknown-     Android Phone       MALE  0m60l8k2ey       en
# 57659      -unknown-     Android Phone       MALE  i9elr7r4z4       en
# 57968      -unknown-     Android Phone     FEMALE  ellj2b9pdn       en
# 58576      -unknown-     Android Phone     FEMALE  itvyshsm3h       en
# 58828      -unknown-     Android Phone       MALE  e5tt6sgmog       en
# 59186  Chrome Mobile     Android Phone  -unknown-  ba2tipwepj       en
# 60173      -unknown-     Android Phone       MALE  6t4hmcdgih       en
# 60268      -unknown-     Android Phone     FEMALE  9klefmsyfl       en
#
#       signup_app  signup_flow signup_method  timestamp_first_active
# 388          Web            3         basic          20100411065602
# 673          Web            2         basic          20100525155541
# 1040         Web            0      facebook          20100714230556
# 1177         Web            3      facebook          20100725234419
# 1200         Web            2         basic          20100727190447
# 1239         Web            0         basic          20100730055204
# 1257         Web            3      facebook          20100801071023
# 1308         Web            3         basic          20100806133725
# 1474         Web            2      facebook          20100821225214
# 1502         Web            3         basic          20100824205045
# 1826         Web            2      facebook          20100921134556
# 1860         Web            2         basic          20100923114758
# 2228         Web            0      facebook          20101029182448
# 2582         Web            3      facebook          20101206173457
# 3818         Web            2      facebook          20110322000910
# 4292         Web            0         basic          20110417062116
# 5091         Web            0         basic          20110523195033
# 5331         Web            2      facebook          20110602005444
# 5549         Web            2         basic          20110610005853
# 5638         Web            0         basic          20110613041718
# 5706         Web            2         basic          20110615061029
# 5710         Web            2         basic          20110615085200
# 5735         Web            2      facebook          20110616024716
# 5989         Web            2      facebook          20110627012116
# 6695         Web            2         basic          20110719165328
# 6925         Web            6         basic          20110726183314
# 7097         Web            3         basic          20110731100727
# 7185         Web            2         basic          20110802162143
# 7360         Web            2      facebook          20110807105600
# 7505         Web            3         basic          20110811204428
# ...          ...          ...           ...                     ...
# 32624    Android           23         basic          20140816111233
# 32878        Web            0         basic          20140816204519
# 33882    Android           23         basic          20140818105020
# 34179        Web            0         basic          20140818220951
# 37137    Android           12        google          20140823033304
# 37792        Web            0         basic          20140824051010
# 39437        Web            0         basic          20140826164544
# 39469    Android           23         basic          20140826172115
# 40954    Android           23         basic          20140828054052
# 43932    Android           12        google          20140902003659
# 44602        Web            0         basic          20140902235107
# 45381    Android           12        google          20140904005903
# 45586    Android           12        google          20140904060406
# 45617    Android           23         basic          20140904073738
# 47647    Android           23         basic          20140907222228
# 47761    Android           12        google          20140908011013
# 49302    Android           12        google          20140910061547
# 49575    Android           23         basic          20140910192510
# 53555    Android           23      facebook          20140917000410
# 53817    Android           23         basic          20140917103905
# 55313        Web            0         basic          20140919211315
# 55620    Android           23         basic          20140920075303
# 55957    Android           23         basic          20140921000901
# 57659    Android           23         basic          20140923192719
# 57968    Android           12        google          20140924032524
# 58576    Android           23         basic          20140925000850
# 58828    Android           12        google          20140925152432
# 59186    Android           23         basic          20140926023217
# 60173    Android           12        google          20140927234214
# 60268    Android           12        google          20140928030031
#
# [850 rows x 16 columns]

# %%
df_2[df_2.age>110].count()
# Out:
# affiliate_channel          850
# affiliate_provider         850
# age                        850
# country_destination        801
# date_account_created       850
# date_first_booking         382
# first_affiliate_tracked    815
# first_browser              850
# first_device_type          850
# gender                     850
# id                         850
# language                   850
# signup_app                 850
# signup_flow                850
# signup_method              850
# timestamp_first_active     850
# dtype: int64

# %%
df_2[df_2.age<15]
# Out:
#        affiliate_channel affiliate_provider  age country_destination  \
# 193        sem-non-brand             google  5.0                  FR
# 482                other         craigslist  5.0                  IT
# 642               direct             direct  5.0                 NDF
# 660               direct             direct  5.0                 NDF
# 776                other         craigslist  5.0                 NDF
# 780               direct             direct  5.0                 NDF
# 781              content             google  5.0                 NDF
# 812        sem-non-brand             google  5.0                  US
# 816               direct             direct  5.0                 NDF
# 837               direct             direct  5.0                 NDF
# 855               direct             direct  5.0                  US
# 880        sem-non-brand               vast  5.0                 NDF
# 911                other              other  5.0                 NDF
# 921                other         craigslist  5.0                  US
# 935                  seo             google  5.0                 NDF
# 966                other         craigslist  5.0                 NDF
# 983        sem-non-brand               vast  5.0                 NDF
# 1183       sem-non-brand             google  5.0                 NDF
# 1197       sem-non-brand               vast  5.0                 NDF
# 1201               other         craigslist  5.0                 NDF
# 1296                 seo             google  5.0                 NDF
# 1307              direct             direct  4.0                  IT
# 1319       sem-non-brand             google  5.0                 NDF
# 1344               other         craigslist  5.0                 NDF
# 1390                 seo             google  5.0                 NDF
# 1422                 seo             google  5.0                  GB
# 1454              direct             direct  4.0                 NDF
# 1467              direct             direct  4.0                 NDF
# 1488                 seo             google  5.0                 NDF
# 1514                 seo             google  5.0                 NDF
# 1533               other         craigslist  5.0                 NDF
# 1545              direct             direct  5.0                 NDF
# 1547           sem-brand             google  5.0                  US
# 1555               other         craigslist  5.0                 NDF
# 1567              direct             direct  5.0                 NDF
# 1573       sem-non-brand             google  5.0                 NDF
# 1582              direct             direct  5.0                 NDF
# 1632                 seo             google  5.0                 NDF
# 1652              direct             direct  5.0                 NDF
# 1680                 seo             google  5.0                 NDF
# 1682       sem-non-brand             google  5.0                 NDF
# 1688           sem-brand             google  5.0                  FR
# 1690              direct             direct  5.0                  DE
# 1693       sem-non-brand             google  5.0                 NDF
# 1736       sem-non-brand             google  5.0                 NDF
# 1780               other         craigslist  5.0                 NDF
# 1786               other         craigslist  5.0                 NDF
# 1804              direct             direct  5.0                 NDF
# 5749               other         craigslist  2.0               other
# 76786      sem-non-brand             google  2.0                 NDF
# 79675             direct             direct  2.0                  US
# 83117      sem-non-brand             google  1.0                 NDF
# 84865             direct             direct  2.0                 NDF
# 89289          sem-brand             google  2.0                  US
# 106447            direct             direct  2.0                  ES
# 191312            direct             direct  2.0                 NDF
# 194600            direct             direct  1.0                 NDF
# 49834             direct             direct  1.0                 NaN
# 55848             direct             direct  1.0                 NaN
#
#        date_account_created date_first_booking first_affiliate_tracked  \
# 193              2010-03-06         2010-03-08                     NaN
# 482              2010-04-29         2010-04-29           tracked-other
# 642              2010-05-20                NaN                     NaN
# 660              2010-05-24                NaN               untracked
# 776              2010-06-07                NaN               untracked
# 780              2010-06-07                NaN                  linked
# 781              2010-06-07                NaN                  linked
# 812              2010-06-14         2010-06-18               untracked
# 816              2010-06-14                NaN                     NaN
# 837              2010-06-16                NaN               untracked
# 855              2010-06-19         2010-06-22               untracked
# 880              2010-06-23                NaN                  linked
# 911              2010-06-27                NaN                  linked
# 921              2010-06-28         2010-06-28                     NaN
# 935              2010-06-29                NaN                     NaN
# 966              2010-07-03                NaN                     NaN
# 983              2010-07-06                NaN                  linked
# 1183             2010-07-26                NaN                     NaN
# 1197             2010-07-27                NaN                     NaN
# 1201             2010-07-27                NaN                     NaN
# 1296             2010-08-05                NaN               untracked
# 1307             2010-08-06         2010-08-07               untracked
# 1319             2010-08-07                NaN                     omg
# 1344             2010-08-09                NaN               untracked
# 1390             2010-08-13                NaN                     NaN
# 1422             2010-08-17         2010-08-19                     NaN
# 1454             2010-08-19                NaN               untracked
# 1467             2010-08-21                NaN               untracked
# 1488             2010-08-23                NaN                     NaN
# 1514             2010-08-25                NaN                  linked
# 1533             2010-08-27                NaN                     NaN
# 1545             2010-08-29                NaN                     NaN
# 1547             2010-08-29         2011-07-06               untracked
# 1555             2010-08-30                NaN                     NaN
# 1567             2010-09-01                NaN               untracked
# 1573             2010-09-01                NaN                     omg
# 1582             2010-09-02                NaN               untracked
# 1632             2010-09-06                NaN                     NaN
# 1652             2010-09-08                NaN                     NaN
# 1680             2010-09-10                NaN               untracked
# 1682             2010-09-11                NaN                  linked
# 1688             2010-09-11         2010-09-14                     NaN
# 1690             2010-09-11         2010-09-15               untracked
# 1693             2010-09-12                NaN                  linked
# 1736             2010-09-14                NaN               untracked
# 1780             2010-09-17                NaN                     NaN
# 1786             2010-09-17                NaN                  linked
# 1804             2010-09-19                NaN                  linked
# 5749             2011-06-16         2012-05-10               untracked
# 76786            2013-05-13                NaN                     omg
# 79675            2013-05-26         2013-06-05                  linked
# 83117            2013-06-11                NaN                     omg
# 84865            2013-06-18                NaN                  linked
# 89289            2013-07-08         2013-07-11                     omg
# 106447           2013-09-10         2013-09-13               untracked
# 191312           2014-05-18                NaN               untracked
# 194600           2014-05-25                NaN               untracked
# 49834            2014-09-11                NaN               untracked
# 55848            2014-09-20                NaN               untracked
#
#           first_browser first_device_type     gender          id language  \
# 193           -unknown-     Other/Unknown     FEMALE  3qsa4lo7eg       en
# 482              Safari       Mac Desktop     FEMALE  rzhouzy2ok       en
# 642           -unknown-     Other/Unknown  -unknown-  5yatk13sko       en
# 660              Safari       Mac Desktop     FEMALE  593gkcul8c       en
# 776              Safari       Mac Desktop       MALE  tu2iorbez0       en
# 780       Mobile Safari            iPhone  -unknown-  zgxbrsgjcn       fr
# 781                  IE   Windows Desktop       MALE  4395zaz8fe       en
# 812                  IE   Windows Desktop  -unknown-  s8wb7qdjqc       en
# 816           -unknown-     Other/Unknown       MALE  ceum3xl08h       en
# 837              Chrome       Mac Desktop     FEMALE  s016mu0c9w       en
# 855              Chrome   Windows Desktop       MALE  jd2rvmhc87       en
# 880     Android Browser     Android Phone     FEMALE  ep67tiywda       en
# 911              Safari       Mac Desktop     FEMALE  svhy4xap9o       en
# 921           -unknown-     Other/Unknown     FEMALE  xth3iy4b8w       en
# 935           -unknown-     Other/Unknown     FEMALE  rreafa3il6       en
# 966           -unknown-     Other/Unknown     FEMALE  pvjp7tft3m       en
# 983       Mobile Safari            iPhone     FEMALE  rivzh42i77       en
# 1183          -unknown-     Other/Unknown     FEMALE  kypji52ew1       en
# 1197          -unknown-     Other/Unknown     FEMALE  ziunnleo0z       en
# 1201          -unknown-     Other/Unknown       MALE  vy6pa5obgz       en
# 1296             Safari       Mac Desktop  -unknown-  7m2g42p45j       en
# 1307             Safari       Mac Desktop       MALE  go0maocn4j       en
# 1319             Chrome   Windows Desktop       MALE  1cze6s2qyw       en
# 1344            Firefox   Windows Desktop       MALE  ei2abgb4yj       en
# 1390          -unknown-     Other/Unknown     FEMALE  pxe3ikz1z5       en
# 1422          -unknown-     Other/Unknown       MALE  hwl62sl83h       en
# 1454             Safari       Mac Desktop       MALE  1y3drbm2zi       en
# 1467             Chrome       Mac Desktop  -unknown-  zcxrv9ge5d       en
# 1488          -unknown-     Other/Unknown       MALE  ipiyamlxki       en
# 1514             Chrome   Windows Desktop  -unknown-  rwpv57t0l8       en
# 1533          -unknown-     Other/Unknown     FEMALE  95ujroa457       en
# 1545          -unknown-     Other/Unknown       MALE  9d8pg250jc       en
# 1547             Safari       Mac Desktop     FEMALE  0qht2kuzpi       en
# 1555          -unknown-     Other/Unknown     FEMALE  uns86j2wco       en
# 1567          -unknown-            iPhone  -unknown-  lxue5bfop9       en
# 1573             Safari       Mac Desktop  -unknown-  x7sc0tkc39       en
# 1582             Chrome       Mac Desktop  -unknown-  qxjcg6oxoy       en
# 1632          -unknown-     Other/Unknown     FEMALE  fn0l3ky4iv       en
# 1652          -unknown-     Other/Unknown     FEMALE  onc6gheng6       en
# 1680             Safari       Mac Desktop     FEMALE  clq4tmvpj0       en
# 1682             Chrome   Windows Desktop       MALE  ehhfhny32a       en
# 1688          -unknown-     Other/Unknown       MALE  bc0qapp1j9       en
# 1690                 IE   Windows Desktop       MALE  ri7nmfafj7       en
# 1693      Chrome Mobile     Android Phone     FEMALE  jlq4zh9eqi       en
# 1736      Mobile Safari            iPhone     FEMALE  ek1ydkxz2r       en
# 1780          -unknown-     Other/Unknown     FEMALE  tk7zn8gd5q       en
# 1786             Safari       Mac Desktop  -unknown-  pc24sqeo86       en
# 1804      Mobile Safari            iPhone       MALE  nazpimyx4j       en
# 5749             Chrome       Mac Desktop  -unknown-  m681qgnxbg       en
# 76786           Firefox   Windows Desktop     FEMALE  qoowplxndc       en
# 79675     Mobile Safari              iPad  -unknown-  crgzx3fstw       en
# 83117     Mobile Safari              iPad  -unknown-  u2bprboi32       en
# 84865            Chrome   Windows Desktop  -unknown-  wzw1movcv8       en
# 89289           Firefox       Mac Desktop     FEMALE  78ztkxfz48       en
# 106447    Mobile Safari              iPad  -unknown-  i55keoopjb       en
# 191312        -unknown-            iPhone       MALE  9nwt5u6w3q       en
# 194600    Chrome Mobile     Android Phone       MALE  3pdleysips       en
# 49834     Mobile Safari            iPhone     FEMALE  icnr9z9f39       en
# 55848         -unknown-            iPhone       MALE  jslo6vm86d       en
#
#        signup_app  signup_flow signup_method  timestamp_first_active
# 193           Web            3         basic          20100306184019
# 482           Web            0      facebook          20100429161617
# 642           Web            2      facebook          20100520212258
# 660           Web            2      facebook          20100524042738
# 776           Web            2      facebook          20100607173548
# 780           Web            0         basic          20100607220745
# 781           Web            2      facebook          20100607235738
# 812           Web            2      facebook          20100614013701
# 816           Web            2      facebook          20100614171620
# 837           Web            2      facebook          20100616151810
# 855           Web            3      facebook          20100619223752
# 880           Web            3      facebook          20100623061552
# 911           Web            2      facebook          20100627061708
# 921           Web            3      facebook          20100628154253
# 935           Web            2      facebook          20100629183520
# 966           Web            3      facebook          20100703211350
# 983           Web            3      facebook          20100706163955
# 1183          Web            2      facebook          20100726055648
# 1197          Web            2      facebook          20100727094532
# 1201          Web            2      facebook          20100727194409
# 1296          Web            3         basic          20100805050642
# 1307          Web            3      facebook          20100806065100
# 1319          Web            3      facebook          20100807135627
# 1344          Web            2      facebook          20100809153422
# 1390          Web            2      facebook          20100813184444
# 1422          Web            2      facebook          20100817002755
# 1454          Web            2      facebook          20100819224047
# 1467          Web            2      facebook          20100821021515
# 1488          Web            3      facebook          20100823175902
# 1514          Web            2      facebook          20100825225400
# 1533          Web            2      facebook          20100827193645
# 1545          Web            2      facebook          20100829152102
# 1547          Web            2      facebook          20100829174258
# 1555          Web            2      facebook          20100830172524
# 1567          Web            2      facebook          20100901000156
# 1573          Web            3      facebook          20100901170939
# 1582          Web            2      facebook          20100902014914
# 1632          Web            2      facebook          20100906190656
# 1652          Web            2      facebook          20100908230804
# 1680          Web            2      facebook          20100910234246
# 1682          Web            2      facebook          20100911004425
# 1688          Web            2      facebook          20100911063840
# 1690          Web            3      facebook          20100911155324
# 1693          Web            3         basic          20100912051651
# 1736          Web            2      facebook          20100914234712
# 1780          Web            2      facebook          20100917200722
# 1786          Web            2      facebook          20100917233233
# 1804          Web            3      facebook          20100919144820
# 5749          Web            2      facebook          20110616193150
# 76786         Web            0         basic          20130513201645
# 79675         Web            0         basic          20130526190832
# 83117         Web            0         basic          20130611060848
# 84865         Web            0         basic          20130618210056
# 89289         Web            0         basic          20130708014715
# 106447        Web            0         basic          20130910134332
# 191312        iOS           25         basic          20140518232245
# 194600      Moweb           24         basic          20140525010743
# 49834         iOS           25         basic          20140911010040
# 55848         iOS           25         basic          20140920205932

# %%
df_2[df_2.age<15].count()
# Out:
# affiliate_channel          59
# affiliate_provider         59
# age                        59
# country_destination        57
# date_account_created       59
# date_first_booking         14
# first_affiliate_tracked    40
# first_browser              59
# first_device_type          59
# gender                     59
# id                         59
# language                   59
# signup_app                 59
# signup_flow                59
# signup_method              59
# timestamp_first_active     59
# dtype: int64

# %% [markdown]
# #### We will find the average value of the age  for all values between 15 & 110 and use it to replace the outlier values

# %%
df_2[(df_2.age<110)&(df_2.age>15)].age.mean()
# Out:
# 36.760967404068936

# %%
#The current age mean taking the effect of the outliers
df_2.age.mean()
# Out:
# 47.145310402631694

# %%
##Replacing the outliers greater than 110 and smaller than 15 by 37
df_2.loc[df_2.age>110,'age']=37
df_2.loc[df_2.age<15,'age']=37

# %%
# checkung max,min and average values after removing outliers

# %%
df_2.age.max()
# Out:
# 110.0

# %%
df_2.age.min()
# Out:
# 15.0

# %%
df_2.age.mean()
# Out:
# 36.8663356041366

# %% [markdown]
# #### mean decreased from 47 to 36.8 after removing outliers

# %%
##Analyzing Gender
df_2['gender'].unique()
# Out:
# array(['-unknown-', 'MALE', 'FEMALE', 'OTHER'], dtype=object)

# %%
df_2['gender'].value_counts()
# Out:
# -unknown-    129480
# FEMALE        77524
# MALE          68209
# OTHER           334
# Name: gender, dtype: int64

# %%
sns.countplot(x='gender',data=df_2)

# %% [markdown]
# #### There are many unknown genders

# %%
sns.countplot(x='gender',data=df_2,hue='country_destination')

# %% [markdown]
# most of the NDF users are of the unknown genders,also most of the users select US regardless the gender

# %%
##Analyzing the affiliate channel
df_2.affiliate_channel.unique()
# Out:
# array(['direct', 'seo', 'other', 'sem-non-brand', 'content', 'sem-brand',
#        'remarketing', 'api'], dtype=object)

# %%
plt.xticks(rotation=90) 
sns.countplot(x='affiliate_channel',data=df_2)

# %%
plt.xticks(rotation=90) 
sns.countplot(x='affiliate_channel',data=df_2,hue='country_destination')

# %%
df_2.affiliate_channel.value_counts()
# Out:
# direct           181571
# sem-brand         36439
# sem-non-brand     20075
# seo               14362
# other              9547
# api                8167
# content            4118
# remarketing        1268
# Name: affiliate_channel, dtype: int64

# %% [markdown]
# #### most of the paid marketing is direct

# %%
##Analyzing the affiliate Provider
df_2.affiliate_provider.unique()
# Out:
# array(['direct', 'google', 'other', 'craigslist', 'facebook', 'vast',
#        'bing', 'meetup', 'facebook-open-graph', 'email-marketing',
#        'yahoo', 'padmapper', 'gsp', 'wayn', 'naver', 'baidu', 'yandex',
#        'daum'], dtype=object)

# %%
df_2.affiliate_provider.nunique()
# Out:
# 18

# %%
plt.xticks(rotation=90) 
sns.countplot(x='affiliate_provider',data=df_2)

# %%
df_2.affiliate_provider.value_counts()
# Out:
# direct                 181270
# google                  65956
# other                   13036
# facebook                 3996
# bing                     3719
# craigslist               3475
# padmapper                 836
# vast                      830
# yahoo                     653
# facebook-open-graph       566
# gsp                       455
# meetup                    358
# email-marketing           270
# naver                      66
# baidu                      32
# yandex                     18
# wayn                        8
# daum                        3
# Name: affiliate_provider, dtype: int64

# %% [markdown]
# #### most of the providers are direct providers

# %%
##Analyzing the first_affiliate
df_2.first_affiliate_tracked.unique()
# Out:
# array(['untracked', 'omg', nan, 'linked', 'tracked-other', 'product',
#        'marketing', 'local ops'], dtype=object)

# %%
plt.xticks(rotation=90) 
sns.countplot(x='first_affiliate_tracked',data=df_2)

# %%
plt.xticks(rotation=90) 
sns.countplot(x='first_affiliate_tracked',data=df_2,hue='country_destination')

# %%
#Analyzing the signup method
df_2.signup_method.unique()
# Out:
# array(['facebook', 'basic', 'google', 'weibo'], dtype=object)

# %%
sns.countplot(x='signup_method',data=df_2,hue='country_destination')

# %%
df_2.signup_method.value_counts()
# Out:
# basic       198222
# facebook     74864
# google        2438
# weibo           23
# Name: signup_method, dtype: int64

# %% [markdown]
# #### most of the users signed up using the basic methods

# %%
#Analyzing the signup flow
df_2.signup_flow.unique()
# Out:
# array([ 0,  3,  2,  1, 24,  8,  6,  5, 10, 25, 12,  4, 16, 15, 20, 21, 23,
#        14], dtype=int64)

# %%
#Analyzing the signup app

# %%
df_2.signup_app.unique()
# Out:
# array(['Web', 'Moweb', 'iOS', 'Android'], dtype=object)

# %%
sns.countplot(x='signup_app',data=df_2,hue='signup_method')

# %%
#Analyzing first device
df_2.first_device_type.unique()
# Out:
# array(['Mac Desktop', 'Windows Desktop', 'iPhone', 'Other/Unknown',
#        'Desktop (Other)', 'Android Tablet', 'iPad', 'Android Phone',
#        'SmartPhone (Other)'], dtype=object)

# %%
plt.xticks(rotation=90) 
sns.countplot(x='first_device_type',data=df_2)

# %%
df_2.first_device_type.value_counts()
# Out:
# Mac Desktop           106328
# Windows Desktop        86948
# iPhone                 39814
# iPad                   18036
# Other/Unknown          11167
# Android Phone           9458
# Android Tablet          2098
# Desktop (Other)         1507
# SmartPhone (Other)       191
# Name: first_device_type, dtype: int64

# %%
sns.countplot(x='signup_app',hue='first_device_type',data=df_2)

# %%
#Analyzing first browser
df_2.first_browser.unique()
# Out:
# array(['Chrome', 'IE', 'Firefox', 'Safari', '-unknown-', 'Mobile Safari',
#        'Chrome Mobile', 'RockMelt', 'Chromium', 'Android Browser',
#        'AOL Explorer', 'Palm Pre web browser', 'Mobile Firefox', 'Opera',
#        'TenFourFox', 'IE Mobile', 'Apple Mail', 'Silk', 'Camino', 'Arora',
#        'BlackBerry Browser', 'SeaMonkey', 'Iron', 'Sogou Explorer',
#        'IceWeasel', 'Opera Mini', 'SiteKiosk', 'Maxthon',
#        'Kindle Browser', 'CoolNovo', 'Conkeror', 'wOSBrowser',
#        'Google Earth', 'Crazy Browser', 'Mozilla', 'OmniWeb',
#        'PS Vita browser', 'NetNewsWire', 'CometBird', 'Comodo Dragon',
#        'Flock', 'Pale Moon', 'Avant Browser', 'Opera Mobile',
#        'Yandex.Browser', 'TheWorld Browser', 'SlimBrowser', 'Epic',
#        'Stainless', 'Googlebot', 'Outlook 2007', 'IceDragon', 'IBrowse',
#        'Nintendo Browser', 'UC Browser'], dtype=object)

# %%
df_2.first_browser.value_counts()
# Out:
# Chrome                  78671
# Safari                  53302
# -unknown-               44394
# Firefox                 38665
# Mobile Safari           29636
# IE                      24744
# Chrome Mobile            3186
# Android Browser          1577
# AOL Explorer              254
# Opera                     228
# Silk                      172
# IE Mobile                 118
# BlackBerry Browser         89
# Chromium                   83
# Mobile Firefox             64
# Maxthon                    60
# Apple Mail                 45
# Sogou Explorer             43
# SiteKiosk                  27
# Iron                       24
# RockMelt                   24
# Yandex.Browser             14
# IceWeasel                  14
# Pale Moon                  13
# CometBird                  12
# SeaMonkey                  12
# Camino                      9
# TenFourFox                  8
# Opera Mini                  8
# wOSBrowser                  7
# CoolNovo                    6
# Avant Browser               4
# Opera Mobile                4
# Mozilla                     3
# OmniWeb                     2
# Crazy Browser               2
# TheWorld Browser            2
# Comodo Dragon               2
# SlimBrowser                 2
# Flock                       2
# NetNewsWire                 1
# Palm Pre web browser        1
# Googlebot                   1
# Epic                        1
# Outlook 2007                1
# IceDragon                   1
# Kindle Browser              1
# Stainless                   1
# Google Earth                1
# Nintendo Browser            1
# IBrowse                     1
# Conkeror                    1
# UC Browser                  1
# Arora                       1
# PS Vita browser             1
# Name: first_browser, dtype: int64

# %%
df_2.language.value_counts()
# Out:
# en           265538
# zh             2634
# fr             1508
# es             1174
# ko             1116
# de              977
# it              633
# ru              508
# ja              345
# pt              322
# sv              176
# nl              134
# tr               92
# da               75
# pl               75
# no               51
# cs               49
# el               30
# th               28
# hu               25
# id               23
# fi               20
# ca                6
# is                5
# hr                2
# -unknown-         1
# Name: language, dtype: int64

# %%
plt.xticks(rotation=90) 
sns.countplot(x='language',data=df_2)

# %%
plt.xticks(rotation=90) 
sns.countplot(x='language',data=df_2,hue='country_destination')

# %%
#Analyzing country destination

# %%
df_2.country_destination.unique()
# Out:
# array(['NDF', 'US', 'other', 'FR', 'CA', 'GB', 'ES', 'IT', 'PT', 'NL',
#        'DE', 'AU', nan], dtype=object)

# %%
df_2.country_destination.value_counts()
# Out:
# NDF      124543
# US        62376
# other     10094
# FR         5023
# IT         2835
# GB         2324
# ES         2249
# CA         1428
# DE         1061
# NL          762
# AU          539
# PT          217
# Name: country_destination, dtype: int64

# %%
df_2.country_destination.describe()
# Out:
# count     213451
# unique        12
# top          NDF
# freq      124543
# Name: country_destination, dtype: object

# %%
sns.countplot(x='country_destination',data=df_2)

# %%
#Analyzing the date of first booking
df_2.date_first_booking.nunique()
# Out:
# 1976

# %%
#checking if we have booking and corresponding NDF
df_2[df_2['country_destination']=='NDF']
# Out:
#        affiliate_channel affiliate_provider   age country_destination  \
# 0                 direct             direct   NaN                 NDF
# 1                    seo             google  38.0                 NDF
# 11                 other         craigslist  47.0                 NDF
# 13                 other         craigslist  37.0                 NDF
# 14                 other         craigslist  36.0                 NDF
# 16                 other         craigslist   NaN                 NDF
# 18                   seo           facebook   NaN                 NDF
# 23                 other         craigslist   NaN                 NDF
# 24                   seo             google  40.0                 NDF
# 26                 other              other   NaN                 NDF
# 31                direct             direct  31.0                 NDF
# 32                   seo             google  31.0                 NDF
# 33                 other         craigslist  29.0                 NDF
# 34                direct             direct  59.0                 NDF
# 35         sem-non-brand             google  49.0                 NDF
# 37                 other         craigslist  30.0                 NDF
# 38         sem-non-brand              other   NaN                 NDF
# 39                 other         craigslist  35.0                 NDF
# 40                 other         craigslist  26.0                 NDF
# 42                direct             direct  29.0                 NDF
# 43                 other         craigslist   NaN                 NDF
# 48                 other         craigslist   NaN                 NDF
# 50                 other         craigslist  30.0                 NDF
# 53                 other         craigslist  28.0                 NDF
# 56                 other         craigslist  53.0                 NDF
# 59                 other         craigslist   NaN                 NDF
# 60                direct             direct   NaN                 NDF
# 61                 other         craigslist  39.0                 NDF
# 62                 other         craigslist   NaN                 NDF
# 65                direct             direct  40.0                 NDF
# ...                  ...                ...   ...                 ...
# 213417         sem-brand             google  46.0                 NDF
# 213418            direct             direct   NaN                 NDF
# 213419            direct             direct   NaN                 NDF
# 213420            direct             direct   NaN                 NDF
# 213421            direct             direct   NaN                 NDF
# 213422            direct             direct   NaN                 NDF
# 213423            direct             direct  20.0                 NDF
# 213424            direct             direct  32.0                 NDF
# 213425            direct             direct  30.0                 NDF
# 213426            direct             direct   NaN                 NDF
# 213427            direct             direct   NaN                 NDF
# 213428            direct             direct   NaN                 NDF
# 213429            direct             direct   NaN                 NDF
# 213430            direct             direct  19.0                 NDF
# 213431            direct             direct   NaN                 NDF
# 213432            direct             direct  31.0                 NDF
# 213433         sem-brand             google   NaN                 NDF
# 213434               seo           facebook   NaN                 NDF
# 213435               seo             google   NaN                 NDF
# 213436            direct             direct   NaN                 NDF
# 213437            direct             direct   NaN                 NDF
# 213438            direct             direct   NaN                 NDF
# 213440            direct             direct  24.0                 NDF
# 213442         sem-brand             google   NaN                 NDF
# 213444            direct             direct   NaN                 NDF
# 213446         sem-brand             google  32.0                 NDF
# 213447            direct             direct   NaN                 NDF
# 213448            direct             direct  32.0                 NDF
# 213449             other              other   NaN                 NDF
# 213450            direct             direct   NaN                 NDF
#
#        date_account_created date_first_booking first_affiliate_tracked  \
# 0                2010-06-28                NaN               untracked
# 1                2011-05-25                NaN               untracked
# 11               2010-01-05                NaN               untracked
# 13               2010-01-05                NaN                  linked
# 14               2010-01-07                NaN               untracked
# 16               2010-01-07                NaN                     NaN
# 18               2010-01-08                NaN                     NaN
# 23               2010-01-11                NaN               untracked
# 24               2010-01-11                NaN               untracked
# 26               2010-01-12                NaN               untracked
# 31               2010-01-14                NaN                     NaN
# 32               2010-01-14                NaN               untracked
# 33               2010-01-14                NaN                     NaN
# 34               2010-01-15                NaN               untracked
# 35               2010-01-15                NaN                     NaN
# 37               2010-01-15                NaN               untracked
# 38               2010-01-15                NaN                     omg
# 39               2010-01-16                NaN               untracked
# 40               2010-01-16                NaN                  linked
# 42               2010-01-21                NaN                     NaN
# 43               2010-01-21                NaN                     NaN
# 48               2010-01-24                NaN               untracked
# 50               2010-01-25                NaN                     NaN
# 53               2010-01-26                NaN                  linked
# 56               2010-01-27                NaN                  linked
# 59               2010-01-28                NaN               untracked
# 60               2010-01-29                NaN               untracked
# 61               2010-01-29                NaN               untracked
# 62               2010-01-29                NaN                     NaN
# 65               2010-01-30                NaN               untracked
# ...                     ...                ...                     ...
# 213417           2014-06-30                NaN                     omg
# 213418           2014-06-30                NaN               untracked
# 213419           2014-06-30                NaN               untracked
# 213420           2014-06-30                NaN                  linked
# 213421           2014-06-30                NaN                  linked
# 213422           2014-06-30                NaN               untracked
# 213423           2014-06-30                NaN               untracked
# 213424           2014-06-30                NaN                  linked
# 213425           2014-06-30                NaN                  linked
# 213426           2014-06-30                NaN               untracked
# 213427           2014-06-30                NaN                  linked
# 213428           2014-06-30                NaN               untracked
# 213429           2014-06-30                NaN               untracked
# 213430           2014-06-30                NaN                  linked
# 213431           2014-06-30                NaN               untracked
# 213432           2014-06-30                NaN           tracked-other
# 213433           2014-06-30                NaN               untracked
# 213434           2014-06-30                NaN                 product
# 213435           2014-06-30                NaN               untracked
# 213436           2014-06-30                NaN               untracked
# 213437           2014-06-30                NaN               untracked
# 213438           2014-06-30                NaN               untracked
# 213440           2014-06-30                NaN               untracked
# 213442           2014-06-30                NaN                     omg
# 213444           2014-06-30                NaN                  linked
# 213446           2014-06-30                NaN                     omg
# 213447           2014-06-30                NaN                  linked
# 213448           2014-06-30                NaN               untracked
# 213449           2014-06-30                NaN           tracked-other
# 213450           2014-06-30                NaN               untracked
#
#         first_browser first_device_type     gender          id language  \
# 0              Chrome       Mac Desktop  -unknown-  gxn3p5htnn       en
# 1              Chrome       Mac Desktop       MALE  820tgsjxq7       en
# 11          -unknown-            iPhone     FEMALE  om1ss59ys8       en
# 13            Firefox       Mac Desktop     FEMALE  dy3rgx56cu       en
# 14      Mobile Safari            iPhone     FEMALE  ju3h98ch3w       en
# 16          -unknown-     Other/Unknown  -unknown-  2dwbwkx056       en
# 18          -unknown-     Other/Unknown  -unknown-  cxlg85pg1r       en
# 23             Safari       Mac Desktop  -unknown-  jha93x042q       en
# 24            Firefox       Mac Desktop     FEMALE  7i49vnuav6       en
# 26          -unknown-     Other/Unknown  -unknown-  bjg0m5otl3       en
# 31          -unknown-     Other/Unknown       MALE  pggg2sj27u       en
# 32          -unknown-     Other/Unknown  -unknown-  mo2v5h3nti       en
# 33          -unknown-     Other/Unknown       MALE  qthj88nnc7       en
# 34             Chrome   Windows Desktop       MALE  x9gnxoun57       en
# 35          -unknown-     Other/Unknown  -unknown-  ugy4obax11       en
# 37             Chrome   Windows Desktop       MALE  ul0b29nhr6       en
# 38            Firefox   Windows Desktop  -unknown-  7yzz3iv0ji       en
# 39             Safari       Mac Desktop     FEMALE  myunxar49t       en
# 40            Firefox   Windows Desktop       MALE  jpne62dhz8       en
# 42          -unknown-     Other/Unknown     FEMALE  2981o5kr7b       en
# 43          -unknown-     Other/Unknown  -unknown-  69xzq1jxkq       en
# 48                 IE   Windows Desktop  -unknown-  2cji4lpjr3       en
# 50          -unknown-     Other/Unknown  -unknown-  22r42sgc0a       en
# 53             Chrome   Windows Desktop       MALE  jtm5s5dhwx       en
# 56             Chrome    Android Tablet     FEMALE  bgel0c0qic       en
# 59             Chrome   Windows Desktop  -unknown-  rwa710uoxj       en
# 60      Mobile Safari            iPhone  -unknown-  p968flw686       en
# 61      Mobile Safari            iPhone       MALE  b2iuaury7k       en
# 62          -unknown-     Other/Unknown  -unknown-  5dp8dxiayg       en
# 65             Safari       Mac Desktop     FEMALE  wtwg1l6pir       en
# ...               ...               ...        ...         ...      ...
# 213417         Chrome   Windows Desktop     FEMALE  zhf38bsj36       en
# 213418         Chrome   Windows Desktop  -unknown-  u6h23bsnzv       en
# 213419        Firefox   Windows Desktop  -unknown-  whl3u790pe       en
# 213420         Safari       Mac Desktop  -unknown-  so90y4lyii       en
# 213421        Firefox       Mac Desktop  -unknown-  c98s3h7kgj       en
# 213422             IE   Windows Desktop  -unknown-  ytmpiwb8hj       en
# 213423      -unknown-            iPhone     FEMALE  3dx1jk6yk2       en
# 213424         Chrome   Windows Desktop     FEMALE  hcfj07iowv       en
# 213425         Chrome   Windows Desktop     FEMALE  l1f71f9vsj       en
# 213426  Chrome Mobile     Android Phone  -unknown-  15bj4ahmhf       en
# 213427         Chrome   Desktop (Other)  -unknown-  qwpybxfjdl       en
# 213428      -unknown-     Android Phone  -unknown-  k4t61wuvyq       en
# 213429      -unknown-            iPhone  -unknown-  mhh7b52z44       en
# 213430         Chrome       Mac Desktop  -unknown-  79wk7k2k5t       en
# 213431        Firefox   Windows Desktop  -unknown-  ftwmocvwlq       en
# 213432         Safari       Mac Desktop       MALE  rg7ayg1tob       en
# 213433  Mobile Safari              iPad  -unknown-  2f24umzkuv       en
# 213434         Chrome       Mac Desktop  -unknown-  or77n2ojuj       en
# 213435         Chrome   Windows Desktop  -unknown-  0a5bnb9bs4       en
# 213436      -unknown-            iPhone  -unknown-  6fzrn49sfn       en
# 213437      -unknown-    Android Tablet  -unknown-  r0jq0devgy       en
# 213438      -unknown-            iPhone  -unknown-  v5lq9bj8gv       en
# 213440  Mobile Safari            iPhone     FEMALE  04y8115avm       en
# 213442         Chrome       Mac Desktop  -unknown-  rf0ay567js       en
# 213444         Chrome   Windows Desktop  -unknown-  40o1ivh6cb       en
# 213446         Safari       Mac Desktop       MALE  zxodksqpep       en
# 213447         Chrome   Windows Desktop  -unknown-  mhewnxesx9       en
# 213448        Firefox       Mac Desktop  -unknown-  6o3arsjbb4       en
# 213449  Mobile Safari            iPhone  -unknown-  jh95kwisub       en
# 213450      -unknown-            iPhone  -unknown-  nw9fwlyb5f       en
#
#        signup_app  signup_flow signup_method  timestamp_first_active
# 0             Web            0      facebook          20090319043255
# 1             Web            0      facebook          20090523174809
# 11            Web            0         basic          20100105051812
# 13            Web            0         basic          20100105083259
# 14            Web            0         basic          20100107055820
# 16            Web            0         basic          20100107215125
# 18            Web            0         basic          20100108015641
# 23            Web            0         basic          20100111224015
# 24            Web            0         basic          20100111230808
# 26            Web            0         basic          20100112155420
# 31            Web            0         basic          20100114060757
# 32            Web            0         basic          20100114084926
# 33            Web            0         basic          20100114175209
# 34            Web            0         basic          20100115055053
# 35            Web            0         basic          20100115082711
# 37            Web            0         basic          20100115231651
# 38            Web            0         basic          20100115234132
# 39            Web            0         basic          20100116154942
# 40            Web            0         basic          20100116215943
# 42            Web            0         basic          20100121070939
# 43            Web            0         basic          20100121183725
# 48            Web            0         basic          20100124083507
# 50            Web            0         basic          20100125184230
# 53            Web            0         basic          20100126002245
# 56            Web            0         basic          20100127031620
# 59            Web            0         basic          20100128100127
# 60            Web            0         basic          20100129032157
# 61            Web            0         basic          20100129093908
# 62            Web            0         basic          20100129173619
# 65            Web            0         basic          20100130161608
# ...           ...          ...           ...                     ...
# 213417        Web            0         basic          20140630230934
# 213418        Web            0         basic          20140630230950
# 213419        Web            0         basic          20140630231044
# 213420        Web            0         basic          20140630231101
# 213421        Web            0         basic          20140630231137
# 213422        Web            0         basic          20140630231246
# 213423        iOS           25      facebook          20140630231548
# 213424        Web            0      facebook          20140630231859
# 213425        Web            0      facebook          20140630232119
# 213426      Moweb            0         basic          20140630232331
# 213427        Web            0         basic          20140630232539
# 213428    Android           23         basic          20140630232634
# 213429        iOS           25         basic          20140630232712
# 213430        Web            0         basic          20140630233132
# 213431        Web            0         basic          20140630233203
# 213432        Web            0      facebook          20140630233224
# 213433        Web            0         basic          20140630233427
# 213434        Web            0         basic          20140630233640
# 213435        Web            0         basic          20140630233851
# 213436        iOS           25         basic          20140630234113
# 213437    Android           23         basic          20140630234243
# 213438        iOS           25         basic          20140630234429
# 213440        iOS           25         basic          20140630234933
# 213442        Web            0         basic          20140630235309
# 213444        Web            0         basic          20140630235352
# 213446        Web            0         basic          20140630235636
# 213447        Web            0         basic          20140630235719
# 213448        Web            0         basic          20140630235754
# 213449        iOS           25         basic          20140630235822
# 213450        iOS           25         basic          20140630235824
#
# [124543 rows x 16 columns]

# %%
df_2[df_2['country_destination']!='NDF']['date_first_booking'].isnull().sum()
# Out:
# 62096

# %% [markdown]
# #### therefore if we have a country destination then we have the date of this booking,note that the 62096 are the test set which has ofcourse missing target values

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275547 entries, 0 to 62095
# Data columns (total 16 columns):
# affiliate_channel          275547 non-null object
# affiliate_provider         275547 non-null object
# age                        158681 non-null float64
# country_destination        213451 non-null object
# date_account_created       275547 non-null object
# date_first_booking         88908 non-null object
# first_affiliate_tracked    269462 non-null object
# first_browser              275547 non-null object
# first_device_type          275547 non-null object
# gender                     275547 non-null object
# id                         275547 non-null object
# language                   275547 non-null object
# signup_app                 275547 non-null object
# signup_flow                275547 non-null int64
# signup_method              275547 non-null object
# timestamp_first_active     275547 non-null int64
# dtypes: float64(1), int64(2), object(13)
# memory usage: 45.7+ MB

# %%
#Analyzing date account created
df_2['date_account_created'].isnull().sum()
# Out:
# 0

# %%
equal_dates=df_2[df_2.date_account_created == df_2.date_first_booking]
equal_dates
# Out:
#        affiliate_channel affiliate_provider   age country_destination  \
# 9                  other         craigslist  46.0                  US
# 19                direct             direct  29.0                  FR
# 22                   seo             google  40.0                  US
# 28                direct             direct  35.0                  FR
# 36                direct             direct  31.0                  US
# 47                 other         craigslist   NaN                  US
# 58                direct             direct  52.0                  US
# 63                direct             direct   NaN                  CA
# 70                 other              other   NaN                  US
# 80                 other              other   NaN               other
# 84                 other         craigslist  32.0                  US
# 104               direct             direct   NaN                  US
# 107               direct             direct  30.0                  FR
# 112               direct             direct   NaN                  US
# 113               direct             direct   NaN                  US
# 118                other         craigslist  43.0                  US
# 121               direct             direct  36.0                  US
# 134                  seo             google   NaN                  US
# 142               direct             direct   NaN                  GB
# 146                  seo             google  33.0                  GB
# 147        sem-non-brand              other  38.0                  US
# 175        sem-non-brand              other   NaN                  US
# 179               direct             direct   NaN                  US
# 181                other         craigslist  35.0                  US
# 196                other         craigslist   NaN                  US
# 201                other         craigslist  33.0                  US
# 206                  seo             google  35.0                  US
# 209               direct             direct  40.0                  US
# 213                  seo           facebook  45.0                  US
# 218              content             google  57.0                  US
# ...                  ...                ...   ...                 ...
# 213131            direct             direct  22.0                  US
# 213148            direct             direct  46.0                  US
# 213151            direct             direct  27.0                  US
# 213153               seo             google  25.0                  US
# 213156         sem-brand             google  31.0                  US
# 213172            direct             direct   NaN               other
# 213175             other              other  41.0               other
# 213185               seo             google  28.0               other
# 213188            direct             direct  39.0                  FR
# 213192            direct             direct   NaN                  IT
# 213193         sem-brand             google   NaN                  FR
# 213194         sem-brand             google   NaN                  GB
# 213195            direct             direct  35.0                  US
# 213211            direct             direct  55.0                  US
# 213219            direct             direct  27.0                  IT
# 213221               seo             google   NaN                  US
# 213226         sem-brand             google   NaN                  DE
# 213228         sem-brand             google  50.0                  US
# 213234            direct             direct   NaN                  US
# 213235            direct             direct  45.0                  US
# 213251         sem-brand             google  26.0                  US
# 213268               seo             google  22.0                  GB
# 213279            direct             direct  22.0               other
# 213285         sem-brand               bing  39.0                  US
# 213313            direct             direct  50.0               other
# 213315            direct             direct  50.0                  US
# 213369            direct             direct   NaN                  ES
# 213376            direct             direct   NaN                  US
# 213407         sem-brand             google  21.0                  ES
# 213415         sem-brand             google  55.0                  FR
#
#        date_account_created date_first_booking first_affiliate_tracked  \
# 9                2010-01-04         2010-01-04                     omg
# 19               2010-01-10         2010-01-10               untracked
# 22               2010-01-11         2010-01-11               untracked
# 28               2010-01-13         2010-01-13                     NaN
# 36               2010-01-15         2010-01-15                  linked
# 47               2010-01-24         2010-01-24                     NaN
# 58               2010-01-27         2010-01-27               untracked
# 63               2010-01-29         2010-01-29                     NaN
# 70               2010-02-02         2010-02-02                     NaN
# 80               2010-02-06         2010-02-06                     NaN
# 84               2010-02-07         2010-02-07                  linked
# 104              2010-02-13         2010-02-13               untracked
# 107              2010-02-15         2010-02-15               untracked
# 112              2010-02-16         2010-02-16                     NaN
# 113              2010-02-16         2010-02-16           tracked-other
# 118              2010-02-17         2010-02-17                  linked
# 121              2010-02-18         2010-02-18                  linked
# 134              2010-02-22         2010-02-22                     omg
# 142              2010-02-24         2010-02-24                  linked
# 146              2010-02-24         2010-02-24                  linked
# 147              2010-02-24         2010-02-24               untracked
# 175              2010-03-02         2010-03-02               untracked
# 179              2010-03-03         2010-03-03                     NaN
# 181              2010-03-03         2010-03-03               untracked
# 196              2010-03-07         2010-03-07                     NaN
# 201              2010-03-08         2010-03-08               untracked
# 206              2010-03-10         2010-03-10               untracked
# 209              2010-03-10         2010-03-10                  linked
# 213              2010-03-11         2010-03-11                     omg
# 218              2010-03-12         2010-03-12               untracked
# ...                     ...                ...                     ...
# 213131           2014-06-30         2014-06-30                  linked
# 213148           2014-06-30         2014-06-30                  linked
# 213151           2014-06-30         2014-06-30               untracked
# 213153           2014-06-30         2014-06-30                  linked
# 213156           2014-06-30         2014-06-30                     omg
# 213172           2014-06-30         2014-06-30                 product
# 213175           2014-06-30         2014-06-30                  linked
# 213185           2014-06-30         2014-06-30                  linked
# 213188           2014-06-30         2014-06-30                     omg
# 213192           2014-06-30         2014-06-30                  linked
# 213193           2014-06-30         2014-06-30                     omg
# 213194           2014-06-30         2014-06-30               untracked
# 213195           2014-06-30         2014-06-30               untracked
# 213211           2014-06-30         2014-06-30               untracked
# 213219           2014-06-30         2014-06-30               untracked
# 213221           2014-06-30         2014-06-30                  linked
# 213226           2014-06-30         2014-06-30                     omg
# 213228           2014-06-30         2014-06-30                     omg
# 213234           2014-06-30         2014-06-30               untracked
# 213235           2014-06-30         2014-06-30               untracked
# 213251           2014-06-30         2014-06-30                     omg
# 213268           2014-06-30         2014-06-30               untracked
# 213279           2014-06-30         2014-06-30                  linked
# 213285           2014-06-30         2014-06-30                     omg
# 213313           2014-06-30         2014-06-30                  linked
# 213315           2014-06-30         2014-06-30                     omg
# 213369           2014-06-30         2014-06-30               untracked
# 213376           2014-06-30         2014-06-30               untracked
# 213407           2014-06-30         2014-06-30                     omg
# 213415           2014-06-30         2014-06-30                     omg
#
#           first_browser first_device_type     gender          id language  \
# 9               Firefox       Mac Desktop  -unknown-  6uh8zyj2gn       en
# 19               Chrome       Mac Desktop     FEMALE  gdka1q5ktd       en
# 22            -unknown-            iPhone  -unknown-  80f7dwscrn       en
# 28            -unknown-     Other/Unknown  -unknown-  tp6x3md0n4       en
# 36               Safari       Mac Desktop     FEMALE  7my0vrljxc       en
# 47            -unknown-     Other/Unknown  -unknown-  ngai8kt2yi       en
# 58              Firefox   Windows Desktop       MALE  fp6ndcm5ak       en
# 63            -unknown-     Other/Unknown  -unknown-  ranh94tmin       en
# 70            -unknown-     Other/Unknown  -unknown-  b9gu8uoxxw       en
# 80            -unknown-     Other/Unknown  -unknown-  jzw5p68a5u       en
# 84               Chrome   Windows Desktop     FEMALE  prqnudhgdx       en
# 104              Chrome   Windows Desktop  -unknown-  uzlk5vzgh4       en
# 107              Chrome   Windows Desktop     FEMALE  2c543qkuic       en
# 112           -unknown-     Other/Unknown  -unknown-  z1smu76iek       en
# 113       Mobile Safari              iPad  -unknown-  mdhde4y8ak       en
# 118              Chrome   Windows Desktop     FEMALE  0sjhzy6z9q       en
# 121              Safari       Mac Desktop  -unknown-  tt4tf7arx9       en
# 134             Firefox       Mac Desktop  -unknown-  woz3bp8egc       en
# 142             Firefox       Mac Desktop  -unknown-  xx5xwvpmyj       en
# 146              Safari       Mac Desktop     FEMALE  y2wks1ljcu       en
# 147              Safari       Mac Desktop       MALE  mcdh2s9owp       en
# 175              Safari       Mac Desktop  -unknown-  yyikx9ztzu       en
# 179           -unknown-     Other/Unknown  -unknown-  k9zs5iak6w       en
# 181              Chrome       Mac Desktop       MALE  ju7u7y9bo1       en
# 196           -unknown-     Other/Unknown  -unknown-  v31grxlt55       en
# 201              Safari       Mac Desktop       MALE  gwtsd4te19       en
# 206              Chrome       Mac Desktop     FEMALE  z4gv6bmyy7       en
# 209              Safari       Mac Desktop  -unknown-  jdy1ic9k4m       en
# 213              Safari       Mac Desktop     FEMALE  l6b51zsk0b       en
# 218              Chrome       Mac Desktop     FEMALE  9pthv2dj2u       en
# ...                 ...               ...        ...         ...      ...
# 213131           Chrome       Mac Desktop       MALE  b0cm091qa1       en
# 213148    Mobile Safari            iPhone     FEMALE  kzswck7pf8       en
# 213151          Firefox   Windows Desktop     FEMALE  yw2owj34w2       en
# 213153           Chrome       Mac Desktop  -unknown-  58f7t4n68g       en
# 213156           Safari       Mac Desktop     FEMALE  xmpg09l5pi       en
# 213172           Chrome   Windows Desktop  -unknown-  6pxya5gn5y       en
# 213175    Mobile Safari            iPhone     FEMALE  j3hzk3xj3q       en
# 213185           Chrome   Windows Desktop     FEMALE  jo2hxlxgt4       en
# 213188           Chrome   Windows Desktop       MALE  qgbi13z7h1       en
# 213192           Chrome   Windows Desktop  -unknown-  k2myrhy2gn       en
# 213193           Chrome       Mac Desktop  -unknown-  2h5v6hvnqv       en
# 213194           Chrome       Mac Desktop  -unknown-  7t92c7uotu       en
# 213195           Chrome       Mac Desktop       MALE  s56esyj5k3       en
# 213211               IE   Windows Desktop     FEMALE  rdwjonddty       en
# 213219          Firefox   Windows Desktop       MALE  zluoqk9bbx       en
# 213221          Firefox       Mac Desktop  -unknown-  9peypg6kxj       de
# 213226           Chrome   Windows Desktop  -unknown-  gy20e5orhs       en
# 213228               IE   Windows Desktop       MALE  fmvtmnt5qy       en
# 213234  Android Browser     Android Phone  -unknown-  5jez6p69c5       en
# 213235          Firefox   Windows Desktop     FEMALE  k5emtrp6s2       en
# 213251          Firefox       Mac Desktop       MALE  itx7byjq6z       en
# 213268           Chrome   Windows Desktop       MALE  gj1oghtlge       en
# 213279           Chrome       Mac Desktop     FEMALE  0cy56unpvk       en
# 213285          Firefox   Windows Desktop       MALE  mk4kyaqyfd       en
# 213313    Mobile Safari            iPhone       MALE  1wrvm4jg29       en
# 213315           Chrome       Mac Desktop     FEMALE  orh0dyailr       en
# 213369           Chrome   Windows Desktop  -unknown-  q7s9qir6xu       en
# 213376    Mobile Safari            iPhone  -unknown-  i1lzm2k3wr       en
# 213407    Mobile Safari              iPad     FEMALE  iu1abga5nx       en
# 213415               IE    Android Tablet  -unknown-  7plqriggxp       en
#
#        signup_app  signup_flow signup_method  timestamp_first_active
# 9             Web            0         basic          20100104023758
# 19            Web            0         basic          20100110010817
# 22            Web            0         basic          20100111031438
# 28            Web            0         basic          20100113044650
# 36            Web            0         basic          20100115221929
# 47            Web            0         basic          20100124020049
# 58            Web            0         basic          20100127232016
# 63            Web            0         basic          20100129182105
# 70            Web            0         basic          20100202050231
# 80            Web            3         basic          20100206070403
# 84            Web            0         basic          20100207014229
# 104           Web            2         basic          20100213194447
# 107           Web            3         basic          20100215005131
# 112           Web            2         basic          20100216024630
# 113           Web            3         basic          20100216070141
# 118           Web            2         basic          20100217012630
# 121           Web            3         basic          20100218044803
# 134           Web            0         basic          20100222083900
# 142           Web            3         basic          20100224005533
# 146           Web            3         basic          20100224153808
# 147           Web            3      facebook          20100224165748
# 175           Web            3         basic          20100302040703
# 179           Web            3         basic          20100303020604
# 181           Web            2         basic          20100303095409
# 196           Web            3         basic          20100307175723
# 201           Web            0         basic          20100308182916
# 206           Web            3         basic          20100310042648
# 209           Web            2         basic          20100310182903
# 213           Web            3         basic          20100311021035
# 218           Web            3         basic          20100312040441
# ...           ...          ...           ...                     ...
# 213131        Web            0         basic          20140630140236
# 213148      Moweb            0         basic          20140630151117
# 213151        Web            0      facebook          20140630151431
# 213153        Web            0         basic          20140630152554
# 213156        Web            0         basic          20140630153347
# 213172        Web            0         basic          20140630162506
# 213175        Web            0         basic          20140630163453
# 213185        Web            0         basic          20140630165352
# 213188        Web            0         basic          20140630165643
# 213192        Web            0         basic          20140630170237
# 213193        Web            0         basic          20140630170338
# 213194        Web            0         basic          20140630170704
# 213195        Web            0         basic          20140630170732
# 213211        Web            0      facebook          20140630173730
# 213219        Web            0         basic          20140630174425
# 213221        Web            0         basic          20140630174809
# 213226        Web            0         basic          20140630180215
# 213228        Web            0         basic          20140630180656
# 213234        Web            0         basic          20140630181451
# 213235        Web            0      facebook          20140630181541
# 213251        Web            0         basic          20140630184035
# 213268        Web            0      facebook          20140630190808
# 213279        Web            0         basic          20140630192421
# 213285        Web            0      facebook          20140630192944
# 213313        Web            0      facebook          20140630201214
# 213315        Web            0         basic          20140630201230
# 213369        Web            0         basic          20140630215348
# 213376        Web            0         basic          20140630220218
# 213407        Web            0      facebook          20140630224635
# 213415        Web            0         basic          20140630230136
#
# [21404 rows x 16 columns]

# %% [markdown]
# #### We have only 21k user(about 25% dates of first booking) created the account and booked their first trip at the same day

# %%
#Changing the format of date_account_created to datetime
df_2.date_account_created=pd.to_datetime(df_2.date_account_created)

# %%
df_2.dtypes
# Out:
# affiliate_channel                  object
# affiliate_provider                 object
# age                               float64
# country_destination                object
# date_account_created       datetime64[ns]
# date_first_booking                 object
# first_affiliate_tracked            object
# first_browser                      object
# first_device_type                  object
# gender                             object
# id                                 object
# language                           object
# signup_app                         object
# signup_flow                         int64
# signup_method                      object
# timestamp_first_active              int64
# dtype: object

# %%
## splitting the date account created column to 3 cloumns(year,month,day)
df_2['dac_year']=df_2.date_account_created.dt.year
df_2['dac_month']=df_2.date_account_created.dt.month
df_2['dac_day']=df_2.date_account_created.dt.day

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275547 entries, 0 to 62095
# Data columns (total 19 columns):
# affiliate_channel          275547 non-null object
# affiliate_provider         275547 non-null object
# age                        158681 non-null float64
# country_destination        213451 non-null object
# date_account_created       275547 non-null datetime64[ns]
# date_first_booking         88908 non-null object
# first_affiliate_tracked    269462 non-null object
# first_browser              275547 non-null object
# first_device_type          275547 non-null object
# gender                     275547 non-null object
# id                         275547 non-null object
# language                   275547 non-null object
# signup_app                 275547 non-null object
# signup_flow                275547 non-null int64
# signup_method              275547 non-null object
# timestamp_first_active     275547 non-null int64
# dac_year                   275547 non-null int64
# dac_month                  275547 non-null int64
# dac_day                    275547 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(12)
# memory usage: 52.0+ MB

# %%
sns.countplot(x='dac_month',data=df_2,hue='country_destination')

# %%
#Analyzing first active
df_2['timestamp_first_active']=pd.to_datetime(df_2['timestamp_first_active'])

# %%
df_2['timestamp_first_active']
# Out:
# 0       1970-01-01 05:34:50.319043255
# 1       1970-01-01 05:34:50.523174809
# 2       1970-01-01 05:34:50.609231247
# 3       1970-01-01 05:34:51.031060129
# 4       1970-01-01 05:34:51.208061105
# 5       1970-01-01 05:35:00.101215619
# 6       1970-01-01 05:35:00.102012558
# 7       1970-01-01 05:35:00.103191905
# 8       1970-01-01 05:35:00.104004211
# 9       1970-01-01 05:35:00.104023758
# 10      1970-01-01 05:35:00.104194251
# 11      1970-01-01 05:35:00.105051812
# 12      1970-01-01 05:35:00.105060859
# 13      1970-01-01 05:35:00.105083259
# 14      1970-01-01 05:35:00.107055820
# 15      1970-01-01 05:35:00.107204555
# 16      1970-01-01 05:35:00.107215125
# 17      1970-01-01 05:35:00.107224625
# 18      1970-01-01 05:35:00.108015641
# 19      1970-01-01 05:35:00.110010817
# 20      1970-01-01 05:35:00.110152120
# 21      1970-01-01 05:35:00.110220941
# 22      1970-01-01 05:35:00.111031438
# 23      1970-01-01 05:35:00.111224015
# 24      1970-01-01 05:35:00.111230808
# 25      1970-01-01 05:35:00.112131444
# 26      1970-01-01 05:35:00.112155420
# 27      1970-01-01 05:35:00.112205949
# 28      1970-01-01 05:35:00.113044650
# 29      1970-01-01 05:35:00.113064333
#                      ...
# 62066   1970-01-01 05:35:40.930231454
# 62067   1970-01-01 05:35:40.930231518
# 62068   1970-01-01 05:35:40.930231952
# 62069   1970-01-01 05:35:40.930232126
# 62070   1970-01-01 05:35:40.930232237
# 62071   1970-01-01 05:35:40.930232253
# 62072   1970-01-01 05:35:40.930232331
# 62073   1970-01-01 05:35:40.930232507
# 62074   1970-01-01 05:35:40.930232551
# 62075   1970-01-01 05:35:40.930232613
# 62076   1970-01-01 05:35:40.930233113
# 62077   1970-01-01 05:35:40.930233305
# 62078   1970-01-01 05:35:40.930233535
# 62079   1970-01-01 05:35:40.930233902
# 62080   1970-01-01 05:35:40.930234128
# 62081   1970-01-01 05:35:40.930234425
# 62082   1970-01-01 05:35:40.930234515
# 62083   1970-01-01 05:35:40.930234551
# 62084   1970-01-01 05:35:40.930234612
# 62085   1970-01-01 05:35:40.930234617
# 62086   1970-01-01 05:35:40.930234703
# 62087   1970-01-01 05:35:40.930234751
# 62088   1970-01-01 05:35:40.930234904
# 62089   1970-01-01 05:35:40.930235000
# 62090   1970-01-01 05:35:40.930235019
# 62091   1970-01-01 05:35:40.930235232
# 62092   1970-01-01 05:35:40.930235306
# 62093   1970-01-01 05:35:40.930235408
# 62094   1970-01-01 05:35:40.930235430
# 62095   1970-01-01 05:35:40.930235901
# Name: timestamp_first_active, Length: 275547, dtype: datetime64[ns]

# %%
## splitting the time first active column to 2 cloumns(date,time)
df_2['tfa_date']=df_2['timestamp_first_active'].dt.date
df_2['tfa_time']=df_2['timestamp_first_active'].dt.time

# %%
df_2.head()
# Out:
#   affiliate_channel affiliate_provider   age country_destination  \
# 0            direct             direct   NaN                 NDF
# 1               seo             google  38.0                 NDF
# 2            direct             direct  56.0                  US
# 3            direct             direct  42.0               other
# 4            direct             direct  41.0                  US
#
#   date_account_created date_first_booking first_affiliate_tracked  \
# 0           2010-06-28                NaN               untracked
# 1           2011-05-25                NaN               untracked
# 2           2010-09-28         2010-08-02               untracked
# 3           2011-12-05         2012-09-08               untracked
# 4           2010-09-14         2010-02-18               untracked
#
#   first_browser first_device_type     gender  ... language signup_app  \
# 0        Chrome       Mac Desktop  -unknown-  ...       en        Web
# 1        Chrome       Mac Desktop       MALE  ...       en        Web
# 2            IE   Windows Desktop     FEMALE  ...       en        Web
# 3       Firefox       Mac Desktop     FEMALE  ...       en        Web
# 4        Chrome       Mac Desktop  -unknown-  ...       en        Web
#
#   signup_flow  signup_method        timestamp_first_active dac_year  \
# 0           0       facebook 1970-01-01 05:34:50.319043255     2010
# 1           0       facebook 1970-01-01 05:34:50.523174809     2011
# 2           3          basic 1970-01-01 05:34:50.609231247     2010
# 3           0       facebook 1970-01-01 05:34:51.031060129     2011
# 4           0          basic 1970-01-01 05:34:51.208061105     2010
#
#    dac_month  dac_day    tfa_date         tfa_time
# 0          6       28  1970-01-01  05:34:50.319043
# 1          5       25  1970-01-01  05:34:50.523174
# 2          9       28  1970-01-01  05:34:50.609231
# 3         12        5  1970-01-01  05:34:51.031060
# 4          9       14  1970-01-01  05:34:51.208061
#
# [5 rows x 21 columns]

# %%
df_2.shape
# Out:
# (275547, 21)

# %%
equal_dates2=df_2[df_2.date_account_created == df_2.tfa_date]
equal_dates2
# Out:
# Empty DataFrame
# Columns: [affiliate_channel, affiliate_provider, age, country_destination, date_account_created, date_first_booking, first_affiliate_tracked, first_browser, first_device_type, gender, id, language, signup_app, signup_flow, signup_method, timestamp_first_active, dac_year, dac_month, dac_day, tfa_date, tfa_time]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# #### No account created at the same time of the first activity

# %%
##some additional analysis

# %%
sns.countplot(x=df_2[df_2['language']=='en']['country_destination'])

# %%
df_2['language'].unique()
# Out:
# array(['en', 'fr', 'de', 'es', 'it', 'pt', 'zh', 'ko', 'ja', 'ru', 'pl',
#        'el', 'sv', 'nl', 'hu', 'da', 'id', 'fi', 'no', 'tr', 'th', 'cs',
#        'hr', 'ca', 'is', '-unknown-'], dtype=object)

# %%
sns.countplot(x='dac_month',data=df_2,hue='country_destination')

# %% [markdown]
# #### most of the bookings took place in june

# %%
sns.countplot(x=df_2[df_2['dac_month']==8]['country_destination'])

# %% [markdown]
# ### Missing Values

# %%
df_2.shape
# Out:
# (275547, 21)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275547 entries, 0 to 62095
# Data columns (total 21 columns):
# affiliate_channel          275547 non-null object
# affiliate_provider         275547 non-null object
# age                        158681 non-null float64
# country_destination        213451 non-null object
# date_account_created       275547 non-null datetime64[ns]
# date_first_booking         88908 non-null object
# first_affiliate_tracked    269462 non-null object
# first_browser              275547 non-null object
# first_device_type          275547 non-null object
# gender                     275547 non-null object
# id                         275547 non-null object
# language                   275547 non-null object
# signup_app                 275547 non-null object
# signup_flow                275547 non-null int64
# signup_method              275547 non-null object
# timestamp_first_active     275547 non-null datetime64[ns]
# dac_year                   275547 non-null int64
# dac_month                  275547 non-null int64
# dac_day                    275547 non-null int64
# tfa_date                   275547 non-null object
# tfa_time                   275547 non-null object
# dtypes: datetime64[ns](2), float64(1), int64(4), object(14)
# memory usage: 56.2+ MB

# %% [markdown]
# #### Since the date of first booking has many missing values in the train set and is totally abscent in test set so i'll drop it

# %%
df_2.drop(['date_first_booking'],axis=1,inplace=True)

# %%
df_2.shape
# Out:
# (275547, 20)

# %%
##i'll fill the missing values of the age by the mean value

# %%
df_2.age.fillna(value=37,inplace=True)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275547 entries, 0 to 62095
# Data columns (total 20 columns):
# affiliate_channel          275547 non-null object
# affiliate_provider         275547 non-null object
# age                        275547 non-null float64
# country_destination        213451 non-null object
# date_account_created       275547 non-null datetime64[ns]
# first_affiliate_tracked    269462 non-null object
# first_browser              275547 non-null object
# first_device_type          275547 non-null object
# gender                     275547 non-null object
# id                         275547 non-null object
# language                   275547 non-null object
# signup_app                 275547 non-null object
# signup_flow                275547 non-null int64
# signup_method              275547 non-null object
# timestamp_first_active     275547 non-null datetime64[ns]
# dac_year                   275547 non-null int64
# dac_month                  275547 non-null int64
# dac_day                    275547 non-null int64
# tfa_date                   275547 non-null object
# tfa_time                   275547 non-null object
# dtypes: datetime64[ns](2), float64(1), int64(4), object(13)
# memory usage: 54.1+ MB

# %%
df_2.first_affiliate_tracked.fillna(value='untracked',inplace=True)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275547 entries, 0 to 62095
# Data columns (total 20 columns):
# affiliate_channel          275547 non-null object
# affiliate_provider         275547 non-null object
# age                        275547 non-null float64
# country_destination        213451 non-null object
# date_account_created       275547 non-null datetime64[ns]
# first_affiliate_tracked    275547 non-null object
# first_browser              275547 non-null object
# first_device_type          275547 non-null object
# gender                     275547 non-null object
# id                         275547 non-null object
# language                   275547 non-null object
# signup_app                 275547 non-null object
# signup_flow                275547 non-null int64
# signup_method              275547 non-null object
# timestamp_first_active     275547 non-null datetime64[ns]
# dac_year                   275547 non-null int64
# dac_month                  275547 non-null int64
# dac_day                    275547 non-null int64
# tfa_date                   275547 non-null object
# tfa_time                   275547 non-null object
# dtypes: datetime64[ns](2), float64(1), int64(4), object(13)
# memory usage: 54.1+ MB

# %%
df_2.head()
# Out:
#   affiliate_channel affiliate_provider   age country_destination  \
# 0            direct             direct  37.0                 NDF
# 1               seo             google  38.0                 NDF
# 2            direct             direct  56.0                  US
# 3            direct             direct  42.0               other
# 4            direct             direct  41.0                  US
#
#   date_account_created first_affiliate_tracked first_browser  \
# 0           2010-06-28               untracked        Chrome
# 1           2011-05-25               untracked        Chrome
# 2           2010-09-28               untracked            IE
# 3           2011-12-05               untracked       Firefox
# 4           2010-09-14               untracked        Chrome
#
#   first_device_type     gender          id language signup_app  signup_flow  \
# 0       Mac Desktop  -unknown-  gxn3p5htnn       en        Web            0
# 1       Mac Desktop       MALE  820tgsjxq7       en        Web            0
# 2   Windows Desktop     FEMALE  4ft3gnwmtx       en        Web            3
# 3       Mac Desktop     FEMALE  bjjt8pjhuk       en        Web            0
# 4       Mac Desktop  -unknown-  87mebub9p4       en        Web            0
#
#   signup_method        timestamp_first_active  dac_year  dac_month  dac_day  \
# 0      facebook 1970-01-01 05:34:50.319043255      2010          6       28
# 1      facebook 1970-01-01 05:34:50.523174809      2011          5       25
# 2         basic 1970-01-01 05:34:50.609231247      2010          9       28
# 3      facebook 1970-01-01 05:34:51.031060129      2011         12        5
# 4         basic 1970-01-01 05:34:51.208061105      2010          9       14
#
#      tfa_date         tfa_time
# 0  1970-01-01  05:34:50.319043
# 1  1970-01-01  05:34:50.523174
# 2  1970-01-01  05:34:50.609231
# 3  1970-01-01  05:34:51.031060
# 4  1970-01-01  05:34:51.208061

# %% [markdown]
# #### Dropping unnecessary columns

# %%
df_2.drop(['timestamp_first_active','tfa_date','tfa_time','date_account_created','id'],axis=1,inplace=True)

# %%
df_2.shape
# Out:
# (275547, 15)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275547 entries, 0 to 62095
# Data columns (total 15 columns):
# affiliate_channel          275547 non-null object
# affiliate_provider         275547 non-null object
# age                        275547 non-null float64
# country_destination        213451 non-null object
# first_affiliate_tracked    275547 non-null object
# first_browser              275547 non-null object
# first_device_type          275547 non-null object
# gender                     275547 non-null object
# language                   275547 non-null object
# signup_app                 275547 non-null object
# signup_flow                275547 non-null int64
# signup_method              275547 non-null object
# dac_year                   275547 non-null int64
# dac_month                  275547 non-null int64
# dac_day                    275547 non-null int64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 43.6+ MB

# %%
#Visualization after handling missing values
sns.pairplot(df_2,kind='scatter',palette='coolwarm')

# %% [markdown]
# #### Encoding categorical features

# %%
cat_features=['affiliate_channel','affiliate_provider','first_affiliate_tracked','first_browser','first_device_type','gender','language','signup_app','signup_method']

# %%
df_2.shape
# Out:
# (275547, 15)

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
encoded=df_2[cat_features].apply(encoder.fit_transform)

# %%
encoded.shape
# Out:
# (275547, 9)

# %%
encoded.head()
# Out:
#    affiliate_channel  affiliate_provider  first_affiliate_tracked  \
# 0                  2                   4                        6
# 1                  7                   8                        6
# 2                  2                   4                        6
# 3                  2                   4                        6
# 4                  2                   4                        6
#
#    first_browser  first_device_type  gender  language  signup_app  \
# 0              8                  3       0         6           2
# 1              8                  3       2         6           2
# 2             22                  6       1         6           2
# 3             17                  3       1         6           2
# 4              8                  3       0         6           2
#
#    signup_method
# 0              1
# 1              1
# 2              0
# 3              1
# 4              0

# %%
df_3=df_2.drop(cat_features,axis=1)

# %%
df_3.shape
# Out:
# (275547, 6)

# %%
df_3.head()
# Out:
#     age country_destination  signup_flow  dac_year  dac_month  dac_day
# 0  37.0                 NDF            0      2010          6       28
# 1  38.0                 NDF            0      2011          5       25
# 2  56.0                  US            3      2010          9       28
# 3  42.0               other            0      2011         12        5
# 4  41.0                  US            0      2010          9       14

# %%
df_final=pd.concat([df_3,encoded],axis=1)

# %%
df_final.shape
# Out:
# (275547, 15)

# %%
df_final.head()
# Out:
#     age country_destination  signup_flow  dac_year  dac_month  dac_day  \
# 0  37.0                 NDF            0      2010          6       28
# 1  38.0                 NDF            0      2011          5       25
# 2  56.0                  US            3      2010          9       28
# 3  42.0               other            0      2011         12        5
# 4  41.0                  US            0      2010          9       14
#
#    affiliate_channel  affiliate_provider  first_affiliate_tracked  \
# 0                  2                   4                        6
# 1                  7                   8                        6
# 2                  2                   4                        6
# 3                  2                   4                        6
# 4                  2                   4                        6
#
#    first_browser  first_device_type  gender  language  signup_app  \
# 0              8                  3       0         6           2
# 1              8                  3       2         6           2
# 2             22                  6       1         6           2
# 3             17                  3       1         6           2
# 4              8                  3       0         6           2
#
#    signup_method
# 0              1
# 1              1
# 2              0
# 3              1
# 4              0

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 275547 entries, 0 to 62095
# Data columns (total 15 columns):
# age                        275547 non-null float64
# country_destination        213451 non-null object
# signup_flow                275547 non-null int64
# dac_year                   275547 non-null int64
# dac_month                  275547 non-null int64
# dac_day                    275547 non-null int64
# affiliate_channel          275547 non-null int32
# affiliate_provider         275547 non-null int32
# first_affiliate_tracked    275547 non-null int32
# first_browser              275547 non-null int32
# first_device_type          275547 non-null int32
# gender                     275547 non-null int32
# language                   275547 non-null int32
# signup_app                 275547 non-null int32
# signup_method              275547 non-null int32
# dtypes: float64(1), int32(9), int64(4), object(1)
# memory usage: 34.2+ MB

# %% [markdown]
# #### Separating the train and test datasets

# %%
df_final_train=df_final[:213451]
df_final_test=df_final[213451:]

# %%
df_final_train.shape
# Out:
# (213451, 15)

# %%
df_final_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 213451 entries, 0 to 213450
# Data columns (total 15 columns):
# age                        213451 non-null float64
# country_destination        213451 non-null object
# signup_flow                213451 non-null int64
# dac_year                   213451 non-null int64
# dac_month                  213451 non-null int64
# dac_day                    213451 non-null int64
# affiliate_channel          213451 non-null int32
# affiliate_provider         213451 non-null int32
# first_affiliate_tracked    213451 non-null int32
# first_browser              213451 non-null int32
# first_device_type          213451 non-null int32
# gender                     213451 non-null int32
# language                   213451 non-null int32
# signup_app                 213451 non-null int32
# signup_method              213451 non-null int32
# dtypes: float64(1), int32(9), int64(4), object(1)
# memory usage: 18.7+ MB

# %%
df_final_test.shape
# Out:
# (62096, 15)

# %%
df_final_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62096 entries, 0 to 62095
# Data columns (total 15 columns):
# age                        62096 non-null float64
# country_destination        0 non-null object
# signup_flow                62096 non-null int64
# dac_year                   62096 non-null int64
# dac_month                  62096 non-null int64
# dac_day                    62096 non-null int64
# affiliate_channel          62096 non-null int32
# affiliate_provider         62096 non-null int32
# first_affiliate_tracked    62096 non-null int32
# first_browser              62096 non-null int32
# first_device_type          62096 non-null int32
# gender                     62096 non-null int32
# language                   62096 non-null int32
# signup_app                 62096 non-null int32
# signup_method              62096 non-null int32
# dtypes: float64(1), int32(9), int64(4), object(1)
# memory usage: 5.4+ MB

# %% [markdown]
# #### Defining x,y

# %%
x=df_final_train.drop('country_destination',axis=1)

# %%
x.shape
# Out:
# (213451, 14)

# %%
x.head()
# Out:
#     age  signup_flow  dac_year  dac_month  dac_day  affiliate_channel  \
# 0  37.0            0      2010          6       28                  2
# 1  38.0            0      2011          5       25                  7
# 2  56.0            3      2010          9       28                  2
# 3  42.0            0      2011         12        5                  2
# 4  41.0            0      2010          9       14                  2
#
#    affiliate_provider  first_affiliate_tracked  first_browser  \
# 0                   4                        6              8
# 1                   8                        6              8
# 2                   4                        6             22
# 3                   4                        6             17
# 4                   4                        6              8
#
#    first_device_type  gender  language  signup_app  signup_method
# 0                  3       0         6           2              1
# 1                  3       2         6           2              1
# 2                  6       1         6           2              0
# 3                  3       1         6           2              1
# 4                  3       0         6           2              0

# %%
y=df_final_train['country_destination']

# %%
y.shape
# Out:
# (213451,)

# %% [markdown]
# ### Splitting the data to train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Applying feature scaling(standardization and normalization) but i believe that it will not affect the output as i m going to use algorithms that don't depend on distance

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
sc=StandardScaler()

# %%
x_train_sc=sc.fit_transform(x_train)
x_test_sc=sc.transform(x_test)

# %%
norm=MinMaxScaler()

# %%
x_train_norm=norm.fit_transform(x_train)
x_test_norm=norm.transform(x_test)

# %% [markdown]
# ### Importing classifiers

# %%
###inserting random forest
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()

# %%
###importing decision tree
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()

# %%
### importing KNN
from sklearn.neighbors import KNeighborsClassifier
knc=KNeighborsClassifier()

# %%
### importing xgboost
from xgboost import XGBClassifier
xgb=XGBClassifier()

# %% [markdown]
# #### Applying Forward feature selection

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

# %%
##Using random forest as our estimator
sfs=SFS(estimator=rfc,k_features=7,forward=True,floating=False,verbose=2,scoring=None)

# %%
sfs=sfs.fit(x_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.4s remaining:    0.0s
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   55.5s finished
#
# [2021-02-05 21:08:12] Features: 1/7 -- score: 0.5875850077843096[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.4s remaining:    0.0s
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   54.2s finished
#
# [2021-02-05 21:09:06] Features: 2/7 -- score: 0.5921293967730841[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.5s remaining:    0.0s
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   60.0s finished
#
# [2021-02-05 21:13:29] Features: 6/7 -- score: 0.6236656923591533[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.5s remaining:    0.0s
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   58.4s finished
#
# [2021-02-05 21:14:27] Features: 7/7 -- score: 0.6200583796705684

# %%
sfs.k_feature_names_
# Out:
# ('age',
#  'signup_flow',
#  'dac_year',
#  'gender',
#  'language',
#  'signup_app',
#  'signup_method')

# %%
x_train_rfc=x_train[['age','signup_flow','dac_year','gender','language','signup_app','signup_method']]
x_test_rfc=x_test[['age','signup_flow','dac_year','gender','language','signup_app','signup_method']]

# %%
##Using xgboost as our  estimator
sfs_xgb=SFS(estimator=xgb,k_features=7,forward=True,floating=False,verbose=2,scoring=None)

# %%
sfs_xgb=sfs_xgb.fit(x_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  3.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 36.2min finished
#
# [2021-02-06 05:27:21] Features: 1/7 -- score: 0.5876719972043788[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.9min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 36.1min finished
#
# [2021-02-06 06:03:29] Features: 2/7 -- score: 0.5921494412475587[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  3.2min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 38.0min finished
#
# [2021-02-06 06:41:32] Features: 3/7 -- score: 0.62972266876209[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  3.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 37.9min finished
#
# [2021-02-06 07:19:27] Features: 4/7 -- score: 0.6308671187548761[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  3.8min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 37.6min finished
#
# [2021-02-06 07:57:01] Features: 5/7 -- score: 0.6320182796582889[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  4.0min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 36.0min finished
#
# [2021-02-06 08:33:01] Features: 6/7 -- score: 0.6324131420287875[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  4.4min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 34.1min finished
#
# [2021-02-06 09:07:09] Features: 7/7 -- score: 0.6328281382509724

# %%
sfs_xgb.k_feature_names_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-169-d784e509c58a> in <module>
# ----> 1 sfs_xgb.k_feature_names_
#
# AttributeError: 'SequentialFeatureSelector' object has no attribute 'k_feature_names_'

# %%
x_train_xgb=x_train[['age','signup_flow','dac_year','first_browser','first_device_type','gender','signup_method']]
x_test_xgb=x_test[['age','signup_flow','dac_year','first_browser','first_device_type','gender','signup_method']]

# %%
##Using KNN as our  estimator
sfs_knc=SFS(estimator=knc,k_features=7,forward=True,floating=False,verbose=2,scoring=None)

# %%
sfs_knc=sfs_knc.fit(x_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   58.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 25.1min finished
#
# [2021-02-06 09:32:16] Features: 1/7 -- score: 0.5729092175959998[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   56.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 23.6min finished
#
# [2021-02-06 09:55:50] Features: 2/7 -- score: 0.5660649241941769[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   41.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 14.6min finished
#
# [2021-02-06 10:10:24] Features: 3/7 -- score: 0.5703162422609462[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   50.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 14.7min finished
#
# [2021-02-06 10:25:05] Features: 4/7 -- score: 0.5715200220893775[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  9.9min finished
#
# [2021-02-06 10:34:57] Features: 5/7 -- score: 0.58862213992497[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.4min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 10.3min finished
#
# [2021-02-06 10:45:17] Features: 6/7 -- score: 0.5917613083802363[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.6min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 10.9min finished
#
# [2021-02-06 10:56:10] Features: 7/7 -- score: 0.5914737208949866

# %%
sfs_knc.k_feature_names_
# Out:
# ('age',
#  'dac_year',
#  'affiliate_channel',
#  'affiliate_provider',
#  'gender',
#  'signup_app',
#  'signup_method')

# %%
x_train_knc=x_train[['age','dac_year','affiliate_channel','affiliate_provider','gender','signup_app','signup_method']]
x_test_knc=x_test[['age','dac_year','affiliate_channel','affiliate_provider','gender','signup_app','signup_method']]

# %% [markdown]
# ### Applying dimensionality reduction(PCA)

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
x_train_pca=pca.fit_transform(x_train)
x_test_pca=pca.transform(x_test)

# %% [markdown]
# ## Applying Algorithms

# %%
##Applying Random Forest
rfc.fit(x_train_rfc,y_train)
# Out:
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
pred_rfc=rfc.predict(x_test_rfc)

# %%
##Applying xgboost
xgb.fit(x_train_xgb,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
pred_xgb=xgb.predict(x_test_xgb)

# %%
##Applying KNN

# %%
knc.fit(x_train_knc,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
pred_knc=knc.predict(x_test_knc)

# %% [markdown]
# ## Evaluating the models

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#           AU       0.00      0.00      0.00       171
#           CA       0.00      0.00      0.00       420
#           DE       0.00      0.00      0.00       334
#           ES       0.02      0.00      0.00       686
#           FR       0.06      0.00      0.01      1505
#           GB       0.03      0.00      0.00       748
#           IT       0.00      0.00      0.00       866
#          NDF       0.68      0.85      0.75     37206
#           NL       0.00      0.00      0.00       225
#           PT       0.00      0.00      0.00        77
#           US       0.49      0.44      0.46     18785
#        other       0.08      0.01      0.01      3013
#
#     accuracy                           0.62     64036
#    macro avg       0.11      0.11      0.10     64036
# weighted avg       0.54      0.62      0.57     64036

# %%
print(classification_report(y_test,pred_xgb))
# Out:
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#           AU       0.00      0.00      0.00       171
#           CA       0.00      0.00      0.00       420
#           DE       0.00      0.00      0.00       334
#           ES       0.00      0.00      0.00       686
#           FR       0.00      0.00      0.00      1505
#           GB       0.00      0.00      0.00       748
#           IT       0.00      0.00      0.00       866
#          NDF       0.69      0.86      0.76     37206
#           NL       0.00      0.00      0.00       225
#           PT       0.00      0.00      0.00        77
#           US       0.49      0.46      0.48     18785
#        other       0.00      0.00      0.00      3013
#
#     accuracy                           0.63     64036
#    macro avg       0.10      0.11      0.10     64036
# weighted avg       0.54      0.63      0.58     64036

# %%
print(classification_report(y_test,pred_knc))
# Out:
#               precision    recall  f1-score   support
#
#           AU       0.00      0.00      0.00       171
#           CA       0.02      0.00      0.00       420
#           DE       0.02      0.01      0.01       334
#           ES       0.02      0.00      0.01       686
#           FR       0.04      0.01      0.02      1505
#           GB       0.05      0.01      0.01       748
#           IT       0.02      0.01      0.01       866
#          NDF       0.65      0.84      0.73     37206
#           NL       0.00      0.00      0.00       225
#           PT       0.00      0.00      0.00        77
#           US       0.44      0.33      0.38     18785
#        other       0.09      0.02      0.03      3013
#
#     accuracy                           0.59     64036
#    macro avg       0.11      0.10      0.10     64036
# weighted avg       0.51      0.59      0.54     64036

# %% [markdown]
# #### xgboost has the highest accuracy

# %% [markdown]
# ## Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'n_estimators':[10,100,1000]}

# %%
grid=GridSearchCV(xgb,param_grid,verbose=2,cv=10)

# %%
grid.fit(x_train_xgb,y_train)
# Out:
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] n_estimators=10 .................................................
# [CV] .................................. n_estimators=10, total=   5.7s
# [CV] n_estimators=10 .................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.6s remaining:    0.0s
# [CV] .................................. n_estimators=10, total=   5.4s
# [CV] n_estimators=10 .................................................
# [CV] .................................. n_estimators=10, total=   5.3s
# [CV] n_estimators=10 .................................................
# [CV] .................................. n_estimators=10, total=   5.4s
# [CV] n_estimators=10 .................................................
# [CV] .................................. n_estimators=10, total=   5.7s
# [CV] n_estimators=10 .................................................
# [CV] .................................. n_estimators=10, total=   6.8s
# [CV] n_estimators=10 .................................................
# [CV] .................................. n_estimators=10, total=   5.2s
# [CV] n_estimators=10 .................................................
# [CV] .................................. n_estimators=10, total=   5.2s
# [CV] n_estimators=10 .................................................
# [CV] .................................. n_estimators=10, total=   5.3s
# [CV] n_estimators=10 .................................................
# [CV] .................................. n_estimators=10, total=   5.3s
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total=  50.4s
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total=  50.2s
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total=  50.3s
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total=  53.2s
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total=  51.5s
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total=  50.3s
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total=  50.3s
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total=  50.3s
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total=  50.4s
# [CV] n_estimators=100 ................................................
# [CV] ................................. n_estimators=100, total=  50.2s
# [CV] n_estimators=1000 ...............................................
# [CV] ................................ n_estimators=1000, total= 8.3min
# [CV] n_estimators=1000 ...............................................
# [CV] ................................ n_estimators=1000, total= 8.4min
# [CV] n_estimators=1000 ...............................................
# [CV] ................................ n_estimators=1000, total= 8.3min
# [CV] n_estimators=1000 ...............................................
# [CV] ................................ n_estimators=1000, total= 8.3min
# [CV] n_estimators=1000 ...............................................
# [CV] ................................ n_estimators=1000, total= 8.3min
# [CV] n_estimators=1000 ...............................................
# [CV] ................................ n_estimators=1000, total= 8.3min
# [CV] n_estimators=1000 ...............................................
# [CV] ................................ n_estimators=1000, total= 8.3min
# [CV] n_estimators=1000 ...............................................
# [CV] ................................ n_estimators=1000, total= 8.6min
# [CV] n_estimators=1000 ...............................................
# [CV] ................................ n_estimators=1000, total= 8.3min
# [CV] n_estimators=1000 ...............................................
# [CV] ................................ n_estimators=1000, total= 8.3min
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 92.7min finished
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=3, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=1,
#                                      nthread=None, objective='multi:softprob',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=None, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='warn', n_jobs=None,
#              param_grid={'n_estimators': [10, 100, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
grid.best_score_
# Out:
# 0.6330622762105544

# %%
grid.best_params_
# Out:
# {'n_estimators': 1000}

# %%
grid_pred=grid.predict(x_test_xgb)

# %%
print(classification_report(y_test,grid_pred))
# Out:
# C:\Users\mshiha\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#           AU       0.00      0.00      0.00       171
#           CA       0.00      0.00      0.00       420
#           DE       0.00      0.00      0.00       334
#           ES       0.00      0.00      0.00       686
#           FR       0.00      0.00      0.00      1505
#           GB       0.00      0.00      0.00       748
#           IT       0.00      0.00      0.00       866
#          NDF       0.69      0.86      0.76     37206
#           NL       0.00      0.00      0.00       225
#           PT       0.00      0.00      0.00        77
#           US       0.49      0.46      0.48     18785
#        other       0.00      0.00      0.00      3013
#
#     accuracy                           0.63     64036
#    macro avg       0.10      0.11      0.10     64036
# weighted avg       0.54      0.63      0.58     64036

# %% [markdown]
# #### number of estimators =1000 give the best accuracy

# %% [markdown]
# ## Predicting the Unseen data

# %%
df_final_test.shape
# Out:
# (62096, 15)

# %%
df_final_test.head()
# Out:
#     age country_destination  signup_flow  dac_year  dac_month  dac_day  \
# 0  35.0                 NaN            0      2014          7        1
# 1  37.0                 NaN            0      2014          7        1
# 2  37.0                 NaN            0      2014          7        1
# 3  37.0                 NaN            0      2014          7        1
# 4  37.0                 NaN            0      2014          7        1
#
#    affiliate_channel  affiliate_provider  first_affiliate_tracked  \
# 0                  2                   4                        6
# 1                  2                   4                        6
# 2                  2                   4                        0
# 3                  2                   4                        0
# 4                  2                   4                        6
#
#    first_browser  first_device_type  gender  language  signup_app  \
# 0             30                  8       1         6           1
# 1             30                  8       0         6           1
# 2              8                  6       0         6           2
# 3             22                  6       0         6           2
# 4             43                  3       0         6           2
#
#    signup_method
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0

# %%
x_pred=df_final_test[['age','signup_flow','dac_year','first_browser','first_device_type','gender','signup_method']]

# %%
predicted_country=xgb.predict(x_pred)

# %%
predicted_country
# Out:
# array(['NDF', 'NDF', 'NDF', ..., 'NDF', 'NDF', 'US'], dtype=object)

# %%
submission=pd.DataFrame({'Id':test_users.id,'country':predicted_country})

# %%
submission.to_csv('submission.csv',index=False,encoding='utf-8')

# %%
## Github training

# %%
## test 1
